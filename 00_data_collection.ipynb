# %% [markdown]
# # Get All Tweets with #PodRevDay

# %%
# Get the data
# !snscrape --jsonl twitter-hashtag "#podrevday since:2020-01-01 until:2021-11-10" > 'data/jan20_nov21.json'

# %%
import pandas as pd
from geotext import GeoText

df_tweets = pd.read_json('data/jan20_nov21.json', lines=True)

# %%
df_tweets.shape
# Out:
# (3405, 21)

# %%
# df_tweets.to_csv('data/jan20_oct21.json', index=False)

# %% [markdown]
# # Get User Data

# %%
df_tweets.user[0]
# Out:
# {'username': 'schisnell',
#  'displayname': 'Steve Chisnell',
#  'id': 15436296,
#  'description': 'Not-quite-retired Educator; \nContent Creator, Waywords Studio',
#  'rawDescription': 'Not-quite-retired Educator; \nContent Creator, Waywords Studio',
#  'descriptionUrls': [],
#  'verified': False,
#  'created': '2008-07-15T03:38:32+00:00',
#  'followersCount': 890,
#  'friendsCount': 341,
#  'statusesCount': 3126,
#  'favouritesCount': 594,
#  'listedCount': 22,
#  'mediaCount': 1427,
#  'location': 'Waterford, MI',
#  'protected': False,
#  'linkUrl': 'https://chisnell.com',
#  'linkTcourl': 'https://t.co/igJnXRWX8F',
#  'profileImageUrl': 'https://pbs.twimg.com/profile_images/1428098112267161604/wmgKmXEP_normal.jpg',
#  'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/15436296/1629320098',
#  'url': 'https://twitter.com/schisnell'}

# %%
df_tweets['username'] = df_tweets['url'].str.split('/').str[3]

# %%
pod_rev_users = pd.DataFrame(df_tweets.user.to_list())

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                                  schisnell
# displayname                                          Steve Chisnell
# id                                                         15436296
# description       Not-quite-retired Educator; \nContent Creator,...
# rawDescription    Not-quite-retired Educator; \nContent Creator,...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2008-07-15T03:38:32+00:00
# followersCount                                                  890
# friendsCount                                                    341
# statusesCount                                                  3126
# favouritesCount                                                 594
# listedCount                                                      22
# mediaCount                                                     1427
# location                                              Waterford, MI
# protected                                                     False
# linkUrl                                        https://chisnell.com
# linkTcourl                                  https://t.co/igJnXRWX8F
# profileImageUrl   https://pbs.twimg.com/profile_images/142809811...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/15436296...
# url                                   https://twitter.com/schisnell
#
#                                                                   1  \
# username                                                  PodRevDay
# displayname       Podcast Review Day, a monthly podcast review e...
# id                                              1258481717431750656
# description       On the 8th of every month we share podcast rev...
# rawDescription    On the 8th of every month we share podcast rev...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                 1840
# friendsCount                                                   1946
# statusesCount                                                  5785
# favouritesCount                                                4320
# listedCount                                                       8
# mediaCount                                                      779
# location                                        Republic of Croatia
# protected                                                     False
# linkUrl                                    http://www.podrevday.com
# linkTcourl                                  https://t.co/lc8oz6UEQv
# profileImageUrl   https://pbs.twimg.com/profile_images/144907623...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay
#
#                                                                   2  \
# username                                              LookBehindPod
# displayname                                       LookBehindTheLook
# id                                              1296668496445804544
# description       A beauty podcast that takes a deep dive into i...
# rawDescription    A beauty podcast that takes a deep dive into i...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-08-21T04:40:42+00:00
# followersCount                                                   56
# friendsCount                                                    137
# statusesCount                                                   318
# favouritesCount                                                 260
# listedCount                                                       1
# mediaCount                                                       52
# location                                               New York, NY
# protected                                                     False
# linkUrl                         https://linktr.ee/lookbehindthelook
# linkTcourl                                  https://t.co/4M2BO8S8kH
# profileImageUrl   https://pbs.twimg.com/profile_images/142593762...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12966684...
# url                               https://twitter.com/LookBehindPod
#
#                                                                   3  \
# username                                                  PodRevDay
# displayname       Podcast Review Day, a monthly podcast review e...
# id                                              1258481717431750656
# description       On the 8th of every month we share podcast rev...
# rawDescription    On the 8th of every month we share podcast rev...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                 1840
# friendsCount                                                   1946
# statusesCount                                                  5785
# favouritesCount                                                4320
# listedCount                                                       8
# mediaCount                                                      779
# location                                        Republic of Croatia
# protected                                                     False
# linkUrl                                    http://www.podrevday.com
# linkTcourl                                  https://t.co/lc8oz6UEQv
# profileImageUrl   https://pbs.twimg.com/profile_images/144907623...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay
#
#                                                                   4
# username                                                  Namely90s
# displayname                                      Namely 90s Podcast
# id                                              1258538847601741830
# description       A podcast that takes you back to our childhood...
# rawDescription    A podcast that takes you back to our childhood...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T23:27:31+00:00
# followersCount                                                  544
# friendsCount                                                    290
# statusesCount                                                  1231
# favouritesCount                                                1488
# listedCount                                                       5
# mediaCount                                                      487
# location                                            West Coast, USA
# protected                                                     False
# linkUrl                                https://Namely90s.com/Listen
# linkTcourl                                  https://t.co/DUPGRX7TTj
# profileImageUrl   https://pbs.twimg.com/profile_images/145783140...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12585388...
# url                                   https://twitter.com/Namely90s

# %%
len(set(pod_rev_users.username))
# Out:
# 640

# %%
pod_rev_users = pod_rev_users.drop_duplicates(subset=['username'])
len(pod_rev_users)
# Out:
# 640

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                                  schisnell
# displayname                                          Steve Chisnell
# id                                                         15436296
# description       Not-quite-retired Educator; \nContent Creator,...
# rawDescription    Not-quite-retired Educator; \nContent Creator,...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2008-07-15T03:38:32+00:00
# followersCount                                                  890
# friendsCount                                                    341
# statusesCount                                                  3126
# favouritesCount                                                 594
# listedCount                                                      22
# mediaCount                                                     1427
# location                                              Waterford, MI
# protected                                                     False
# linkUrl                                        https://chisnell.com
# linkTcourl                                  https://t.co/igJnXRWX8F
# profileImageUrl   https://pbs.twimg.com/profile_images/142809811...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/15436296...
# url                                   https://twitter.com/schisnell
#
#                                                                   1  \
# username                                                  PodRevDay
# displayname       Podcast Review Day, a monthly podcast review e...
# id                                              1258481717431750656
# description       On the 8th of every month we share podcast rev...
# rawDescription    On the 8th of every month we share podcast rev...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                 1840
# friendsCount                                                   1946
# statusesCount                                                  5785
# favouritesCount                                                4320
# listedCount                                                       8
# mediaCount                                                      779
# location                                        Republic of Croatia
# protected                                                     False
# linkUrl                                    http://www.podrevday.com
# linkTcourl                                  https://t.co/lc8oz6UEQv
# profileImageUrl   https://pbs.twimg.com/profile_images/144907623...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay
#
#                                                                   2  \
# username                                              LookBehindPod
# displayname                                       LookBehindTheLook
# id                                              1296668496445804544
# description       A beauty podcast that takes a deep dive into i...
# rawDescription    A beauty podcast that takes a deep dive into i...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-08-21T04:40:42+00:00
# followersCount                                                   56
# friendsCount                                                    137
# statusesCount                                                   318
# favouritesCount                                                 260
# listedCount                                                       1
# mediaCount                                                       52
# location                                               New York, NY
# protected                                                     False
# linkUrl                         https://linktr.ee/lookbehindthelook
# linkTcourl                                  https://t.co/4M2BO8S8kH
# profileImageUrl   https://pbs.twimg.com/profile_images/142593762...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12966684...
# url                               https://twitter.com/LookBehindPod
#
#                                                                   4  \
# username                                                  Namely90s
# displayname                                      Namely 90s Podcast
# id                                              1258538847601741830
# description       A podcast that takes you back to our childhood...
# rawDescription    A podcast that takes you back to our childhood...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T23:27:31+00:00
# followersCount                                                  544
# friendsCount                                                    290
# statusesCount                                                  1231
# favouritesCount                                                1488
# listedCount                                                       5
# mediaCount                                                      487
# location                                            West Coast, USA
# protected                                                     False
# linkUrl                                https://Namely90s.com/Listen
# linkTcourl                                  https://t.co/DUPGRX7TTj
# profileImageUrl   https://pbs.twimg.com/profile_images/145783140...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12585388...
# url                                   https://twitter.com/Namely90s
#
#                                                                   5
# username                                              MatthewWinner
# displayname                                       Matthew C. Winner
# id                                                         87759734
# description       Head of Podcasts at @akidsco. Host of Worth No...
# rawDescription    Head of Podcasts at @akidsco. Host of Worth No...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2009-11-05T19:15:18+00:00
# followersCount                                                15864
# friendsCount                                                   3174
# statusesCount                                                 45254
# favouritesCount                                               29561
# listedCount                                                     507
# mediaCount                                                     2933
# location                                                   Maryland
# protected                                                     False
# linkUrl                            https://linktr.ee/matthewcwinner
# linkTcourl                                  https://t.co/6ilmxNFnAR
# profileImageUrl   https://pbs.twimg.com/profile_images/123358296...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/87759734...
# url                               https://twitter.com/MatthewWinner

# %%
print(pod_rev_users.columns)
pod_rev_users.shape
# Out:
# Index(['username', 'displayname', 'id', 'description', 'rawDescription',
#        'descriptionUrls', 'verified', 'created', 'followersCount',
#        'friendsCount', 'statusesCount', 'favouritesCount', 'listedCount',
#        'mediaCount', 'location', 'protected', 'linkUrl', 'linkTcourl',
#        'profileImageUrl', 'profileBannerUrl', 'url'],
#       dtype='object')
# (640, 21)

# %% [markdown]
# # Clean User Data

# %%
keep = ['id','username', 'displayname', 'location', 'created', 'followersCount', 'friendsCount', 'url', 'verified' ]
df_users = pod_rev_users.loc[:, keep]

# %%
def location_extraction (df):
    '''Creates creates a geotext column to extract city and country info if possible'''

    df.loc[:, "location"] = df.loc[:, "location"].fillna("blank")
    df.loc[:, "geotext"] = df.loc[:, "location"].apply(GeoText)
    df.loc[:, 'city'] = df.loc[:, 'geotext'].apply(lambda x: x.cities)
    df.loc[:, 'country'] = df.loc[:, 'geotext'].apply(lambda x: x.countries)
    
    return df

df_users = location_extraction(df_users)

# %%
from geonamescache import GeonamesCache
gc = GeonamesCache()
countries = gc.get_countries()
country_info = pd.DataFrame(countries).T
country_info = country_info.set_index('geonameid').reset_index()
name_code = country_info.loc[:, ["name", "iso3"]]

us_states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
             "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA",
             "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY",
             "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX",
             "UT", "VT", "VA", "WA", "WV", "WI", "WY", "USA", "United States",
             'Seattle', "Los Angeles", "Houston", "Atlanta", "Pittsburgh"]

us_state_names = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", 
               "District ", "of Columbia", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", 
               "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", 
               "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", 
               "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", 
               "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", 
               "Wisconsin", "West Virginia", "Wyoming"]

can_prov_abbrev = {'Alberta': 'AB','British Columbia': 'BC','Manitoba': 'MB', 'New Brunswick': 'NB',
                       'Newfoundland and Labrador': 'NL', 'Northwest Territories': 'NT','Nova Scotia': 'NS','Nunavut': 'NU',
                       'Ontario': 'ON','Prince Edward Island': 'PE', 'Quebec': 'QC','Saskatchewan': 'SK','Yukon': 'YT'}

can_prov_names, can_prov_abbr = zip(*can_prov_abbrev.items())

uk = ["England", 'Wales', "Scotland", 'London', "Manchester", "Isle of Wight", "Northern Ireland", "United Kingdom", 'Bailiwick of Guernsey', "UK", "Hoxton", "Jersey"]

india_city = ["Bangalore", "Delhi", "Hyderabad", "Bengaluru"]

german_city = ["Munich", "Berlin", "eisgau","Hamburg", "Dortmund"]

south_africa = ["South Africa", "Durban", "Johannesburg"]

south_korea = ["Republic of Korea"]

uae = ['UAE', 'Dubai', 'Abu Dhabi']


def replacer(area, name):
    df_users.loc[(df_users.location.str.contains('|'.join(area))), "country"] = name    
    return df_users

def list_to_string(df):
    df["city"] = df['city'].apply(lambda x: "".join(map(str, x)))
    df["country"] = df['country'].apply(lambda x: "".join(map(str, x)))
    
    return df

# %%
def location_cleaner(df):
    df = replacer(can_prov_names, "Canada")
    df = replacer(can_prov_abbrev, "Canada")
    df = replacer(us_state_names, "United States")
    df = replacer(us_states, "United States")
    df = replacer(uk, "United Kingdom")
    df = replacer(german_city, "Germany")
    df = replacer(south_africa, "South Africa")
    df = replacer(india_city, "India")
    df = replacer(uae, 'United Arab Emirates')
    df = replacer(south_korea, "South Korea")
    df.loc[(df.location == "Italia"), "country"] = "Italy" 
    df.loc[(df.location == "Belgrade"), "country"] = "Serbia" 
    df.loc[(df.country == "PolandSerbia"), "country"] = "Poland" 
    df = list_to_string(df)
    
    return df

# %%
df_users = location_cleaner(df_users)
df_users.loc[(df_users.country == "PolandSerbia"), "country"] = "Poland"

# %%
df_users.country.value_counts()
# Out:
#                         302
# United States           212
# United Kingdom           57
# Canada                   26
# Germany                   6
# Ireland                   4
# Croatia                   3
# New Zealand               3
# Australia                 3
# Spain                     3
# Poland                    3
# India                     3
# Malaysia                  2
# South Africa              2
# France                    2
# Nigeria                   1
# Vanuatu                   1
# South Korea               1
# United Arab Emirates      1
# Sweden                    1
# Ecuador                   1
# Japan                     1
# Italy                     1
# Czech Republic            1
# Name: country, dtype: int64

# %%
df_users_full = pd.merge(left=df_users,
                    right=name_code,
                    how='left',
                    left_on='country',
                    right_on='name')

# %%
df_users_full.head()
# Out:
#                     id       username  \
# 0             15436296      schisnell
# 1  1258481717431750656      PodRevDay
# 2  1296668496445804544  LookBehindPod
# 3  1258538847601741830      Namely90s
# 4             87759734  MatthewWinner
#
#                                          displayname             location  \
# 0                                     Steve Chisnell        Waterford, MI
# 1  Podcast Review Day, a monthly podcast review e...  Republic of Croatia
# 2                                  LookBehindTheLook         New York, NY
# 3                                 Namely 90s Podcast      West Coast, USA
# 4                                  Matthew C. Winner             Maryland
#
#                      created  followersCount  friendsCount  \
# 0  2008-07-15T03:38:32+00:00             890           341
# 1  2020-05-07T19:40:12+00:00            1840          1946
# 2  2020-08-21T04:40:42+00:00              56           137
# 3  2020-05-07T23:27:31+00:00             544           290
# 4  2009-11-05T19:15:18+00:00           15864          3174
#
#                                  url  verified  \
# 0      https://twitter.com/schisnell     False
# 1      https://twitter.com/PodRevDay     False
# 2  https://twitter.com/LookBehindPod     False
# 3      https://twitter.com/Namely90s     False
# 4  https://twitter.com/MatthewWinner     False
#
#                                              geotext       city  \
# 0  <geotext.geotext.GeoText object at 0x7f328c5b3...  Waterford
# 1  <geotext.geotext.GeoText object at 0x7f328c5b3...
# 2  <geotext.geotext.GeoText object at 0x7f328c5b3...   New York
# 3  <geotext.geotext.GeoText object at 0x7f328c5b3...
# 4  <geotext.geotext.GeoText object at 0x7f328c5b3...   Maryland
#
#          country           name iso3
# 0  United States  United States  USA
# 1        Croatia        Croatia  HRV
# 2  United States  United States  USA
# 3  United States  United States  USA
# 4  United States  United States  USA

# %% [markdown]
# ## Save the Users

# %%
df_users.to_csv('data/user_data.csv')

# %% [markdown]
# # Merge User's Geographic Data with Tweets

# %%
full_df = pd.merge(left=df_tweets, 
                   right=df_users, 
                   how='left',
                   on='username')


new_path = 'data/tweets_users_nov_21.csv'
full_df.to_csv(new_path, index=False)

# %%
full_df.shape
# Out:
# (3405, 33)

# %%
full_df.head()
# Out:
#                                                url_x  \
# 0  https://twitter.com/schisnell/status/145817632...
# 1  https://twitter.com/PodRevDay/status/145812730...
# 2  https://twitter.com/LookBehindPod/status/14580...
# 3  https://twitter.com/PodRevDay/status/145802367...
# 4  https://twitter.com/Namely90s/status/145793896...
#
#                        date  \
# 0 2021-11-09 20:55:01+00:00
# 1 2021-11-09 17:40:15+00:00
# 2 2021-11-09 15:50:27+00:00
# 3 2021-11-09 10:48:27+00:00
# 4 2021-11-09 05:11:50+00:00
#
#                                              content  \
# 0  Each episode of Fall of Civilizations, Paul Co...
# 1  #podrevday was such a joy yesterday. \n\nLet's...
# 2  Who can I count on for a  #PodRevDay ping pong...
# 3  Thx to everyone that participated in #podrevda...
# 4  Shout out to @WildNightsPod on this #PodRevDay...
#
#                                      renderedContent                 id_x  \
# 0  Each episode of Fall of Civilizations, Paul Co...  1458176320718921731
# 1  #podrevday was such a joy yesterday. \n\nLet's...  1458127309077155844
# 2  Who can I count on for a  #PodRevDay ping pong...  1458099675861557268
# 3  Thx to everyone that participated in #podrevda...  1458023672791412739
# 4  Shout out to @WildNightsPod on this #PodRevDay...  1457938961909776384
#
#                                                 user  \
# 0  {'username': 'schisnell', 'displayname': 'Stev...
# 1  {'username': 'PodRevDay', 'displayname': 'Podc...
# 2  {'username': 'LookBehindPod', 'displayname': '...
# 3  {'username': 'PodRevDay', 'displayname': 'Podc...
# 4  {'username': 'Namely90s', 'displayname': 'Name...
#
#                                             outlinks  \
# 0          [https://fallofcivilizationspodcast.com/]
# 1                         [http://Www.podrevday.com]
# 2  [https://www.podchaser.com/podcasts/look-behin...
# 3                                                 []
# 4                                                 []
#
#                  tcooutlinks  replyCount  retweetCount  ...  \
# 0  [https://t.co/N76ciexkOu]           0             0  ...
# 1  [https://t.co/R2xU7EwapE]           0             0  ...
# 2  [https://t.co/03KUrzvKNN]           0             0  ...
# 3                         []           0             1  ...
# 4                         []           1             1  ...
#
#                                          displayname             location  \
# 0                                     Steve Chisnell        Waterford, MI
# 1  Podcast Review Day, a monthly podcast review e...  Republic of Croatia
# 2                                  LookBehindTheLook         New York, NY
# 3  Podcast Review Day, a monthly podcast review e...  Republic of Croatia
# 4                                 Namely 90s Podcast      West Coast, USA
#
#                      created followersCount friendsCount  \
# 0  2008-07-15T03:38:32+00:00            890          341
# 1  2020-05-07T19:40:12+00:00           1840         1946
# 2  2020-08-21T04:40:42+00:00             56          137
# 3  2020-05-07T19:40:12+00:00           1840         1946
# 4  2020-05-07T23:27:31+00:00            544          290
#
#                                url_y verified  \
# 0      https://twitter.com/schisnell    False
# 1      https://twitter.com/PodRevDay    False
# 2  https://twitter.com/LookBehindPod    False
# 3      https://twitter.com/PodRevDay    False
# 4      https://twitter.com/Namely90s    False
#
#                                              geotext       city        country
# 0  <geotext.geotext.GeoText object at 0x7f328c5b3...  Waterford  United States
# 1  <geotext.geotext.GeoText object at 0x7f328c5b3...                   Croatia
# 2  <geotext.geotext.GeoText object at 0x7f328c5b3...   New York  United States
# 3  <geotext.geotext.GeoText object at 0x7f328c5b3...                   Croatia
# 4  <geotext.geotext.GeoText object at 0x7f328c5b3...             United States
#
# [5 rows x 33 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv(new_path)

# %%
df['count'] = df.groupby('username')['username'].transform('count')

# %%
df.sort_values(by='count')
# Out:
#                                                   url_x  \
# 2630  https://twitter.com/listentothefilm/status/128...
# 326   https://twitter.com/BarkerMcIntosh/status/1446...
# 325   https://twitter.com/musicpodcasts/status/14465...
# 2625  https://twitter.com/thetwoohsix/status/1281018...
# 323   https://twitter.com/Fog_Cast/status/1446514743...
# ...                                                 ...
# 2879  https://twitter.com/PodRevDay/status/127003185...
# 2880  https://twitter.com/PodRevDay/status/127002955...
# 1277  https://twitter.com/PodRevDay/status/139029145...
# 2769  https://twitter.com/PodRevDay/status/127045490...
# 926   https://twitter.com/PodRevDay/status/140809407...
#
#                            date  \
# 2630  2020-07-08 21:38:31+00:00
# 326   2021-10-08 16:11:09+00:00
# 325   2021-10-08 16:33:20+00:00
# 2625  2020-07-09 00:11:11+00:00
# 323   2021-10-08 16:36:04+00:00
# ...                         ...
# 2879  2020-06-08 16:36:03+00:00
# 2880  2020-06-08 16:26:57+00:00
# 1277  2021-05-06 13:04:48+00:00
# 2769  2020-06-09 20:37:08+00:00
# 926   2021-06-24 16:06:02+00:00
#
#                                                 content  \
# 2630  It’s #PodRevDay today. If you like the show pl...
# 326   #podrevday Go listen #90daywinspodcast and lea...
# 325   Music #podcasters love your feedback but so do...
# 2625  Just discovered my movie related podcast is on...
# 323   @GoodpodsHQ @PodRevDay @stephfuccio #PodRevDay...
# ...                                                 ...
# 2879  @PodheroHQ @PodHero DM me if you want some ide...
# 2880  @stephfuccio @RunnymedeCap &amp; @arithisandth...
# 1277  @moogster31 Didnt know these were a thing. Are...
# 2769  A huge #PodRevDay thank you from @stephfuccio\...
# 926   #podrevday peeps, \n@OliverAshKleine has a new...
#
#                                         renderedContent                 id_x  \
# 2630  It’s #PodRevDay today. If you like the show pl...  1280979605214515200
# 326   #podrevday Go listen #90daywinspodcast and lea...  1446508471596240899
# 325   Music #podcasters love your feedback but so do...  1446514054302896132
# 2625  Just discovered my movie related podcast is on...  1281018023378214914
# 323   @GoodpodsHQ @PodRevDay @stephfuccio #PodRevDay...  1446514743871774734
# ...                                                 ...                  ...
# 2879  @PodheroHQ @PodHero DM me if you want some ide...  1270031850912743426
# 2880  @stephfuccio @RunnymedeCap &amp; @arithisandth...  1270029558222409729
# 1277  @moogster31 Didnt know these were a thing. Are...  1390291458079576064
# 2769  A huge #PodRevDay thank you from @stephfuccio\...  1270454907649302528
# 926   #podrevday peeps, \n@OliverAshKleine has a new...  1408094070912729088
#
#                                                    user  \
# 2630  {'username': 'listentothefilm', 'displayname':...
# 326   {'username': 'BarkerMcIntosh', 'displayname': ...
# 325   {'username': 'musicpodcasts', 'displayname': '...
# 2625  {'username': 'thetwoohsix', 'displayname': 'Ma...
# 323   {'username': 'Fog_Cast', 'displayname': 'Throu...
# ...                                                 ...
# 2879  {'username': 'PodRevDay', 'displayname': 'Podc...
# 2880  {'username': 'PodRevDay', 'displayname': 'Podc...
# 1277  {'username': 'PodRevDay', 'displayname': 'Podc...
# 2769  {'username': 'PodRevDay', 'displayname': 'Podc...
# 926   {'username': 'PodRevDay', 'displayname': 'Podc...
#
#                                                outlinks  \
# 2630  ['https://podcasts.apple.com/au/podcast/listen...
# 326   ['https://90daywins.buzzsprout.com', 'https://...
# 325                                                  []
# 2625  ['https://www.podchaser.com/podcasts/the-twooh...
# 323                                                  []
# ...                                                 ...
# 2879                                                 []
# 2880  ['https://www.podchaser.com/articles/community...
# 1277                                                 []
# 2769  ['https://www.instagram.com/tv/CBOhoh6Hj8V/?ig...
# 926                            ['http://project.Email']
#
#                                             tcooutlinks  replyCount  \
# 2630                        ['https://t.co/qaDyqXtrbt']           2
# 326   ['https://t.co/lYqzyn1jIe', 'https://t.co/RR6p...           0
# 325                                                  []           0
# 2625  ['https://t.co/6qfUjkzWGk', 'https://t.co/tGuF...           1
# 323                                                  []           0
# ...                                                 ...         ...
# 2879                                                 []           0
# 2880                        ['https://t.co/iWSMqamcm7']           6
# 1277                                                 []           1
# 2769                        ['https://t.co/Rnl3lmAhoV']           0
# 926                         ['https://t.co/yoQbMY5gTW']           1
#
#       retweetCount  ...                      location  \
# 2630             1  ...                           NaN
# 326              0  ...                   Atlanta, GA
# 325              0  ...                     Tempe, AZ
# 2625             0  ...  Seattle, WA aka The TwoOhSix
# 323              0  ...                           NaN
# ...            ...  ...                           ...
# 2879             0  ...           Republic of Croatia
# 2880            11  ...           Republic of Croatia
# 1277             0  ...           Republic of Croatia
# 2769             0  ...           Republic of Croatia
# 926              2  ...           Republic of Croatia
#
#                         created  followersCount friendsCount  \
# 2630  2020-06-04T11:23:29+00:00             639          791
# 326   2012-10-11T21:20:36+00:00              25           64
# 325   2020-01-22T15:19:38+00:00              90          156
# 2625  2012-01-04T04:48:39+00:00            1142         2230
# 323   2021-10-04T15:57:59+00:00             213          110
# ...                         ...             ...          ...
# 2879  2020-05-07T19:40:12+00:00            1840         1946
# 2880  2020-05-07T19:40:12+00:00            1840         1946
# 1277  2020-05-07T19:40:12+00:00            1840         1946
# 2769  2020-05-07T19:40:12+00:00            1840         1946
# 926   2020-05-07T19:40:12+00:00            1840         1946
#
#                                     url_y verified  \
# 2630  https://twitter.com/listentothefilm    False
# 326    https://twitter.com/BarkerMcIntosh    False
# 325     https://twitter.com/musicpodcasts    False
# 2625      https://twitter.com/thetwoohsix    False
# 323          https://twitter.com/Fog_Cast    False
# ...                                   ...      ...
# 2879        https://twitter.com/PodRevDay    False
# 2880        https://twitter.com/PodRevDay    False
# 1277        https://twitter.com/PodRevDay    False
# 2769        https://twitter.com/PodRevDay    False
# 926         https://twitter.com/PodRevDay    False
#
#                                                 geotext     city  \
# 2630  <geotext.geotext.GeoText object at 0x7f328c0ed...      NaN
# 326   <geotext.geotext.GeoText object at 0x7f328c5f5...  Atlanta
# 325   <geotext.geotext.GeoText object at 0x7f328c5f5...    Tempe
# 2625  <geotext.geotext.GeoText object at 0x7f328c0ed...  Seattle
# 323   <geotext.geotext.GeoText object at 0x7f328c5f5...      NaN
# ...                                                 ...      ...
# 2879  <geotext.geotext.GeoText object at 0x7f328c5b3...      NaN
# 2880  <geotext.geotext.GeoText object at 0x7f328c5b3...      NaN
# 1277  <geotext.geotext.GeoText object at 0x7f328c5b3...      NaN
# 2769  <geotext.geotext.GeoText object at 0x7f328c5b3...      NaN
# 926   <geotext.geotext.GeoText object at 0x7f328c5b3...      NaN
#
#             country count
# 2630            NaN     1
# 326   United States     1
# 325   United States     1
# 2625  United States     1
# 323             NaN     1
# ...             ...   ...
# 2879        Croatia   448
# 2880        Croatia   448
# 1277        Croatia   448
# 2769        Croatia   448
# 926         Croatia   448
#
# [3405 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['url_x', 'date', 'content', 'renderedContent', 'id_x', 'user',
#        'outlinks', 'tcooutlinks', 'replyCount', 'retweetCount', 'likeCount',
#        'quoteCount', 'conversationId', 'lang', 'source', 'sourceUrl',
#        'sourceLabel', 'media', 'retweetedTweet', 'quotedTweet',
#        'mentionedUsers', 'username', 'id_y', 'displayname', 'location',
#        'created', 'followersCount', 'friendsCount', 'url_y', 'verified',
#        'geotext', 'city', 'country', 'count'],
#       dtype='object')

# %%
keep = ['username', 'id_y', 'displayname', 'location',
        'created', 'followersCount', 'friendsCount', 'url_y', 'verified',
        'city', 'country', 'count']

df.loc[:, keep].drop_duplicates().sort_values(by='count').to_csv('data/user_data_count_11_21.csv', index=False)
