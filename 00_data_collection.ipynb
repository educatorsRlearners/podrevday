# %% [markdown]
# # Get All Tweets with #PodRevDay

# %%
# Get the data
# !snscrape --jsonl twitter-hashtag "#podrevday since:2020-01-01 until:2021-04-19" > 'data/jan20_apr21.json'

# %%
import pandas as pd
from geotext import GeoText

df_tweets_old = pd.read_json('data/jan20_mar21.json', lines=True)
df_tweets_new = pd.read_json('data/jan20_apr21.json', lines=True)

# %%
print(df_tweets_old.shape)
print(df_tweets_new.shape)
print(f'Number of tweets last month useing #podrevday: {df_tweets_new.shape[0] - df_tweets_old.shape[0]}')
# Out:
# (1936, 21)
# (2097, 21)
# Number of tweets last month useing #podrevday: 161

# %%
df_tweets_new.head().T
# Out:
#                                                                  0  \
# url              https://twitter.com/StoriesSandman/status/1380...
# date                                     2021-04-09 08:21:29+00:00
# content          Esports and gaming news from @lukaseggen and @...
# renderedContent  Esports and gaming news from @lukaseggen and @...
# id                                             1380435687711731714
# user             {'username': 'StoriesSandman', 'displayname': ...
# outlinks         [https://www.podchaser.com/podcasts/lan-partie...
# tcooutlinks                              [https://t.co/dPz4tTFBDn]
# replyCount                                                       0
# retweetCount                                                     1
# likeCount                                                        0
# quoteCount                                                       0
# conversationId                                 1380435687711731714
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'lukaseggen', 'displayname': 'Lu...
#
#                                                                  1  \
# url              https://twitter.com/StoriesSandman/status/1380...
# date                                     2021-04-09 08:14:37+00:00
# content          THE best Dustin in Podcasting- @dustin_holden ...
# renderedContent  THE best Dustin in Podcasting- @dustin_holden ...
# id                                             1380433956110168068
# user             {'username': 'StoriesSandman', 'displayname': ...
# outlinks         [https://www.podchaser.com/podcasts/dustin-can...
# tcooutlinks                              [https://t.co/2t9VARBTBk]
# replyCount                                                       0
# retweetCount                                                     0
# likeCount                                                        0
# quoteCount                                                       0
# conversationId                                 1380433956110168068
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'dustin_holden', 'displayname': ...
#
#                                                                  2  \
# url              https://twitter.com/StoriesSandman/status/1380...
# date                                     2021-04-09 08:10:51+00:00
# content          Let @ThoughtsByRandy take you for a ride #PodR...
# renderedContent  Let @ThoughtsByRandy take you for a ride #PodR...
# id                                             1380433008163835906
# user             {'username': 'StoriesSandman', 'displayname': ...
# outlinks         [https://www.podchaser.com/podcasts/driving-wi...
# tcooutlinks                              [https://t.co/DvBBc52Dm2]
# replyCount                                                       0
# retweetCount                                                     0
# likeCount                                                        0
# quoteCount                                                       0
# conversationId                                 1380433008163835906
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'ThoughtsByRandy', 'displayname'...
#
#                                                                  3  \
# url              https://twitter.com/CaseyBroda/status/13803654...
# date                                     2021-04-09 03:42:24+00:00
# content          #podrevday review ▶️ Check out my ⭐️⭐️⭐️⭐️⭐️ r...
# renderedContent  #podrevday review ▶️ Check out my ⭐️⭐️⭐️⭐️⭐️ r...
# id                                             1380365453134995456
# user             {'username': 'CaseyBroda', 'displayname': 'Cas...
# outlinks         [https://www.podchaser.com/podcasts/a-most-unu...
# tcooutlinks                              [https://t.co/lRkWvAcIxr]
# replyCount                                                       0
# retweetCount                                                     1
# likeCount                                                        0
# quoteCount                                                       0
# conversationId                                 1380365453134995456
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'Podchaser', 'displayname': 'Pod...
#
#                                                                  4
# url              https://twitter.com/BlackCaseDiary/status/1380...
# date                                     2021-04-09 03:41:35+00:00
# content          With it being #PodRevDay, we had to share the ...
# renderedContent  With it being #PodRevDay, we had to share the ...
# id                                             1380365248293650432
# user             {'username': 'BlackCaseDiary', 'displayname': ...
# outlinks         [https://www.podchaser.com/podcasts/jackie-wat...
# tcooutlinks                              [https://t.co/QW5RG4zFyf]
# replyCount                                                       0
# retweetCount                                                     2
# likeCount                                                        2
# quoteCount                                                       0
# conversationId                                 1380365248293650432
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'JackieWatches', 'displayname': ...

# %% [markdown]
# # Get User Data

# %%
df_tweets_new.user[0]
# Out:
# {'username': 'StoriesSandman',
#  'displayname': 'Sandman Stories Presents',
#  'id': 1228491846013214721,
#  'description': 'Dustin: Narrator, voice actor, educator, folklore enthusiast. Sandmanstoriespresents@gmail.com He/Him. Magister Educationis (literacy)',
#  'rawDescription': 'Dustin: Narrator, voice actor, educator, folklore enthusiast. Sandmanstoriespresents@gmail.com He/Him. Magister Educationis (literacy)',
#  'descriptionUrls': [],
#  'verified': False,
#  'created': '2020-02-15T01:31:09+00:00',
#  'followersCount': 1274,
#  'friendsCount': 1202,
#  'statusesCount': 3903,
#  'favouritesCount': 36945,
#  'listedCount': 11,
#  'mediaCount': 231,
#  'location': 'Republic of Korea',
#  'protected': False,
#  'linkUrl': 'https://linktr.ee/Sandmanstoriespresents',
#  'linkTcourl': 'https://t.co/0AQoI5wYbN',
#  'profileImageUrl': 'https://pbs.twimg.com/profile_images/1300250232106528774/7qh230c7_normal.jpg',
#  'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/1228491846013214721/1581853500',
#  'url': 'https://twitter.com/StoriesSandman'}

# %%
df_tweets_new['username'] = df_tweets_new['url'].str.split('/').str[3]

# %%
#pd.DataFrame(ser.tolist())
pod_rev_users = pd.DataFrame(df_tweets_new.user.to_list())

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                             StoriesSandman
# displayname                                Sandman Stories Presents
# id                                              1228491846013214721
# description       Dustin: Narrator, voice actor, educator, folkl...
# rawDescription    Dustin: Narrator, voice actor, educator, folkl...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-02-15T01:31:09+00:00
# followersCount                                                 1274
# friendsCount                                                   1202
# statusesCount                                                  3903
# favouritesCount                                               36945
# listedCount                                                      11
# mediaCount                                                      231
# location                                          Republic of Korea
# protected                                                     False
# linkUrl                    https://linktr.ee/Sandmanstoriespresents
# linkTcourl                                  https://t.co/0AQoI5wYbN
# profileImageUrl   https://pbs.twimg.com/profile_images/130025023...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12284918...
# url                              https://twitter.com/StoriesSandman
#
#                                                                   1  \
# username                                             StoriesSandman
# displayname                                Sandman Stories Presents
# id                                              1228491846013214721
# description       Dustin: Narrator, voice actor, educator, folkl...
# rawDescription    Dustin: Narrator, voice actor, educator, folkl...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-02-15T01:31:09+00:00
# followersCount                                                 1274
# friendsCount                                                   1202
# statusesCount                                                  3903
# favouritesCount                                               36945
# listedCount                                                      11
# mediaCount                                                      231
# location                                          Republic of Korea
# protected                                                     False
# linkUrl                    https://linktr.ee/Sandmanstoriespresents
# linkTcourl                                  https://t.co/0AQoI5wYbN
# profileImageUrl   https://pbs.twimg.com/profile_images/130025023...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12284918...
# url                              https://twitter.com/StoriesSandman
#
#                                                                   2  \
# username                                             StoriesSandman
# displayname                                Sandman Stories Presents
# id                                              1228491846013214721
# description       Dustin: Narrator, voice actor, educator, folkl...
# rawDescription    Dustin: Narrator, voice actor, educator, folkl...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-02-15T01:31:09+00:00
# followersCount                                                 1274
# friendsCount                                                   1202
# statusesCount                                                  3903
# favouritesCount                                               36945
# listedCount                                                      11
# mediaCount                                                      231
# location                                          Republic of Korea
# protected                                                     False
# linkUrl                    https://linktr.ee/Sandmanstoriespresents
# linkTcourl                                  https://t.co/0AQoI5wYbN
# profileImageUrl   https://pbs.twimg.com/profile_images/130025023...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12284918...
# url                              https://twitter.com/StoriesSandman
#
#                                                                   3  \
# username                                                 CaseyBroda
# displayname                                             Casey Broda
# id                                                        533456292
# description       Podcast Editing, Cover Art, & Social Media Man...
# rawDescription    Podcast Editing, Cover Art, & Social Media Man...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2012-03-22T18:35:49+00:00
# followersCount                                                  140
# friendsCount                                                    298
# statusesCount                                                   643
# favouritesCount                                                4517
# listedCount                                                       0
# mediaCount                                                      184
# location                                      Currently Seattle, WA
# protected                                                     False
# linkUrl                                https://linktr.ee/CaseyBroda
# linkTcourl                                  https://t.co/EvV8vhWnVQ
# profileImageUrl   https://pbs.twimg.com/profile_images/136048576...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/53345629...
# url                                  https://twitter.com/CaseyBroda
#
#                                                                   4
# username                                             BlackCaseDiary
# displayname                         The BCD TV/Film History Podcast
# id                                              1065402848408670209
# description       A TV/Film education podcast hosted by three ol...
# rawDescription    A TV/Film education podcast hosted by three ol...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2018-11-22T00:33:28+00:00
# followersCount                                                 2697
# friendsCount                                                   2127
# statusesCount                                                  4658
# favouritesCount                                                9129
# listedCount                                                      35
# mediaCount                                                     1157
# location                                               Columbus, OH
# protected                                                     False
# linkUrl                       https://www.blackcasediaries.com/blog
# linkTcourl                                  https://t.co/1OXtRWCbQw
# profileImageUrl   https://pbs.twimg.com/profile_images/132330182...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/10654028...
# url                              https://twitter.com/BlackCaseDiary

# %%
len(set(pod_rev_users.username))
# Out:
# 457

# %%
pod_rev_users = pod_rev_users.drop_duplicates(subset=['username'])

# %%
pod_rev_users.head().T
# Out:
#                                                                  0   \
# username                                             StoriesSandman
# displayname                                Sandman Stories Presents
# id                                              1228491846013214721
# description       Dustin: Narrator, voice actor, educator, folkl...
# rawDescription    Dustin: Narrator, voice actor, educator, folkl...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-02-15T01:31:09+00:00
# followersCount                                                 1274
# friendsCount                                                   1202
# statusesCount                                                  3903
# favouritesCount                                               36945
# listedCount                                                      11
# mediaCount                                                      231
# location                                          Republic of Korea
# protected                                                     False
# linkUrl                    https://linktr.ee/Sandmanstoriespresents
# linkTcourl                                  https://t.co/0AQoI5wYbN
# profileImageUrl   https://pbs.twimg.com/profile_images/130025023...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12284918...
# url                              https://twitter.com/StoriesSandman
#
#                                                                  3   \
# username                                                 CaseyBroda
# displayname                                             Casey Broda
# id                                                        533456292
# description       Podcast Editing, Cover Art, & Social Media Man...
# rawDescription    Podcast Editing, Cover Art, & Social Media Man...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2012-03-22T18:35:49+00:00
# followersCount                                                  140
# friendsCount                                                    298
# statusesCount                                                   643
# favouritesCount                                                4517
# listedCount                                                       0
# mediaCount                                                      184
# location                                      Currently Seattle, WA
# protected                                                     False
# linkUrl                                https://linktr.ee/CaseyBroda
# linkTcourl                                  https://t.co/EvV8vhWnVQ
# profileImageUrl   https://pbs.twimg.com/profile_images/136048576...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/53345629...
# url                                  https://twitter.com/CaseyBroda
#
#                                                                  4   \
# username                                             BlackCaseDiary
# displayname                         The BCD TV/Film History Podcast
# id                                              1065402848408670209
# description       A TV/Film education podcast hosted by three ol...
# rawDescription    A TV/Film education podcast hosted by three ol...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2018-11-22T00:33:28+00:00
# followersCount                                                 2697
# friendsCount                                                   2127
# statusesCount                                                  4658
# favouritesCount                                                9129
# listedCount                                                      35
# mediaCount                                                     1157
# location                                               Columbus, OH
# protected                                                     False
# linkUrl                       https://www.blackcasediaries.com/blog
# linkTcourl                                  https://t.co/1OXtRWCbQw
# profileImageUrl   https://pbs.twimg.com/profile_images/132330182...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/10654028...
# url                              https://twitter.com/BlackCaseDiary
#
#                                                                  5   \
# username                                               OracleofDusk
# displayname                                               MJ Bailey
# id                                              1087100443761758208
# description       the story of a reluctant oracle. and maybe... ...
# rawDescription    the story of a reluctant oracle. and maybe... ...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2019-01-20T21:31:57+00:00
# followersCount                                                  808
# friendsCount                                                   1810
# statusesCount                                                  2363
# favouritesCount                                                3772
# listedCount                                                       8
# mediaCount                                                      287
# location
# protected                                                     False
# linkUrl                                  http://oracleofdusk.online
# linkTcourl                                  https://t.co/sTfHhVd0AQ
# profileImageUrl   https://pbs.twimg.com/profile_images/134159538...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/10871004...
# url                                https://twitter.com/OracleofDusk
#
#                                                                  12
# username                                            PodcastOverhaul
# displayname                                        Podcast Overhaul
# id                                              1267168296270540801
# description       Discover a New #Podcast on @PodcastOverhaul. D...
# rawDescription    Discover a New #Podcast on @PodcastOverhaul. D...
# descriptionUrls   [{'text': 'onelink.to/e3j95b', 'url': 'http://...
# verified                                                      False
# created                                   2020-05-31T18:57:27+00:00
# followersCount                                                 2049
# friendsCount                                                    945
# statusesCount                                                  8766
# favouritesCount                                                9170
# listedCount                                                       8
# mediaCount                                                       27
# location                                               Florida, USA
# protected                                                     False
# linkUrl                             https://www.podcastoverhaul.com
# linkTcourl                                  https://t.co/xOgqReZKGJ
# profileImageUrl   https://pbs.twimg.com/profile_images/136202638...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12671682...
# url                             https://twitter.com/PodcastOverhaul

# %%
pod_rev_users.shape
# Out:
# (457, 21)

# %% [markdown]
# # Clean User Data

# %%
df_users = pod_rev_users.loc[:, ['id','username', 'displayname', 'location', 'created', 'followersCount', 'friendsCount', 'url', 'verified' ]]

# %%
def location_extraction (df):
    '''Creates creates a geotext column to extract city and country info if possible'''

    df.loc[:, "location"] = df.loc[:, "location"].fillna("blank")
    df.loc[:, "geotext"] = df.loc[:, "location"].apply(GeoText)
    df.loc[:, 'city'] = df.loc[:, 'geotext'].apply(lambda x: x.cities)
    df.loc[:, 'country'] = df.loc[:, 'geotext'].apply(lambda x: x.countries)
    
    return df

df_users = location_extraction(df_users)

# %%
from geonamescache import GeonamesCache
gc = GeonamesCache()
countries = gc.get_countries()
country_info = pd.DataFrame(countries).T
country_info = country_info.set_index('geonameid').reset_index()
name_code = country_info.loc[:, ["name", "iso3"]]

us_states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
             "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA",
             "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY",
             "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX",
             "UT", "VT", "VA", "WA", "WV", "WI", "WY", "USA", "United States",
             'Seattle', "Los Angeles", "Houston", "Atlanta", "Pittsburgh"]

us_state_names = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", 
               "District ", "of Columbia", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", 
               "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", 
               "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", 
               "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", 
               "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", 
               "Wisconsin", "West Virginia", "Wyoming"]

can_prov_abbrev = {'Alberta': 'AB','British Columbia': 'BC','Manitoba': 'MB', 'New Brunswick': 'NB',
                       'Newfoundland and Labrador': 'NL', 'Northwest Territories': 'NT','Nova Scotia': 'NS','Nunavut': 'NU',
                       'Ontario': 'ON','Prince Edward Island': 'PE', 'Quebec': 'QC','Saskatchewan': 'SK','Yukon': 'YT'}

can_prov_names, can_prov_abbr = zip(*can_prov_abbrev.items())

uk = ["England", 'Wales', "Scotland", 'London', "Manchester", "Isle of Wight", "Northern Ireland", "United Kingdom", 'Bailiwick of Guernsey', "UK", "Hoxton", "Jersey"]

india_city = ["Bangalore", "Delhi", "Hyderabad", "Bengaluru"]

german_city = ["Munich", "Berlin", "eisgau","Hamburg", "Dortmund"]

south_africa = ["South Africa", "Durban", "Johannesburg"]

uae = ['UAE', 'Dubai', 'Abu Dhabi']

def replacer(area, name):
    df_users.loc[(df_users.location.str.contains('|'.join(area))), "country"] = name    
    return df_users

def list_to_string(df):
    df["city"] = df['city'].apply(lambda x: "".join(map(str, x)))
    df["country"] = df['country'].apply(lambda x: "".join(map(str, x)))
    
    return df

# %%
def location_cleaner(df):
    df = replacer(can_prov_names, "Canada")
    df = replacer(can_prov_abbrev, "Canada")
    df = replacer(us_state_names, "United States")
    df = replacer(us_states, "United States")
    df = replacer(uk, "United Kingdom")
    df = replacer(german_city, "Germany")
    df = replacer(south_africa, "South Africa")
    df = replacer(india_city, "India")
    df = replacer(uae, 'United Arab Emirates')
    df.loc[(df.location == "Italia"), "country"] = "Italy" 
    df.loc[(df.location == "Belgrade"), "country"] = "Serbia" 
    df.loc[(df.country == "PolandSerbia"), "country"] = "Poland" 
    df = list_to_string(df)
    
    return df

# %%
df_users = location_cleaner(df_users)
df_users.loc[(df_users.country == "PolandSerbia"), "country"] = "Poland"

# %%
df_users.country.value_counts()
# Out:
#                         202
# United States           160
# United Kingdom           44
# Canada                   22
# Germany                   5
# Australia                 3
# India                     3
# Malaysia                  2
# Poland                    2
# Spain                     2
# Ireland                   2
# Nigeria                   1
# Sweden                    1
# Albania                   1
# Vanuatu                   1
# Italy                     1
# Vietnam                   1
# France                    1
# United Arab Emirates      1
# Ecuador                   1
# New Zealand               1
# Name: country, dtype: int64

# %%
df_users_full = pd.merge(left=df_users,
                    right=name_code,
                    how='left',
                    left_on='country',
                    right_on='name')

# %%
df_users_full.head()
# Out:
#                     id         username                      displayname  \
# 0  1228491846013214721   StoriesSandman         Sandman Stories Presents
# 1            533456292       CaseyBroda                      Casey Broda
# 2  1065402848408670209   BlackCaseDiary  The BCD TV/Film History Podcast
# 3  1087100443761758208     OracleofDusk                        MJ Bailey
# 4  1267168296270540801  PodcastOverhaul                 Podcast Overhaul
#
#                 location                    created  followersCount  \
# 0      Republic of Korea  2020-02-15T01:31:09+00:00            1274
# 1  Currently Seattle, WA  2012-03-22T18:35:49+00:00             140
# 2           Columbus, OH  2018-11-22T00:33:28+00:00            2697
# 3                         2019-01-20T21:31:57+00:00             808
# 4           Florida, USA  2020-05-31T18:57:27+00:00            2049
#
#    friendsCount                                  url  verified  \
# 0          1202   https://twitter.com/StoriesSandman     False
# 1           298       https://twitter.com/CaseyBroda     False
# 2          2127   https://twitter.com/BlackCaseDiary     False
# 3          1810     https://twitter.com/OracleofDusk     False
# 4           945  https://twitter.com/PodcastOverhaul     False
#
#                                              geotext      city        country  \
# 0  <geotext.geotext.GeoText object at 0x7f555512d...
# 1  <geotext.geotext.GeoText object at 0x7f555512d...            United States
# 2  <geotext.geotext.GeoText object at 0x7f555512d...  Columbus  United States
# 3  <geotext.geotext.GeoText object at 0x7f555512d...
# 4  <geotext.geotext.GeoText object at 0x7f55551af...   Florida  United States
#
#             name iso3
# 0            NaN  NaN
# 1  United States  USA
# 2  United States  USA
# 3            NaN  NaN
# 4  United States  USA

# %% [markdown]
# ## Update Followers Data

# %%
df_users.to_csv('data/user_data.csv')

# %% [markdown]
# # Merge User's Geographic Data with Tweets

# %%
full_df = pd.merge(left=df_tweets_new, 
                   right=df_users_full, 
                   how='left',
                   on='username')

full_df.to_csv('data/tweets_users_apr_21.csv', index=False)
