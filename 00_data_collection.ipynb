# %% [markdown]
# # Get All Tweets with #PodRevDay

# %%
# Get the data
# !snscrape --jsonl twitter-hashtag "#podrevday since:2020-01-01 until:2021-03-12" > 'data/jan20_mar21.json'

# %%
import pandas as pd
from geotext import GeoText

df_tweets_old = pd.read_json('data/jan20_feb_21.json', lines=True)
df_tweets_new = pd.read_json('data/jan20_mar21.json', lines=True)

# %%
print(df_tweets_old.shape)
print(df_tweets_new.shape)
print(f'Number of tweets last month useing #podrevday: {df_tweets_new.shape[0] - df_tweets_old.shape[0]}')
# Out:
# (1729, 21)
# (1936, 21)
# Number of tweets last month useing #podrevday: 207

# %%
df_tweets_new.head().T
# Out:
#                                                                  0  \
# url              https://twitter.com/BallsyHistory/status/13701...
# date                                     2021-03-11 21:03:11+00:00
# content          Okay, I'm a little addicted to @podchaser and ...
# renderedContent  Okay, I'm a little addicted to @podchaser and ...
# id                                             1370118124511633413
# user             {'username': 'BallsyHistory', 'displayname': '...
# outlinks         [https://www.podchaser.com/podcasts/infectious...
# tcooutlinks                              [https://t.co/3hMiwEvrV9]
# replyCount                                                       2
# retweetCount                                                     4
# likeCount                                                       10
# quoteCount                                                       0
# conversationId                                 1370118124511633413
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'Podchaser', 'displayname': 'Pod...
#
#                                                                  1  \
# url              https://twitter.com/ODParlayHour/status/136949...
# date                                     2021-03-10 03:58:40+00:00
# content          Check out my ⭐️⭐️⭐️⭐️⭐️ review of  @Contrarian...
# renderedContent  Check out my ⭐️⭐️⭐️⭐️⭐️ review of  @Contrarian...
# id                                             1369497912284217348
# user             {'username': 'ODParlayHour', 'displayname': 'O...
# outlinks         [https://www.podchaser.com/podcasts/the-contra...
# tcooutlinks                              [https://t.co/1Uscnko3TM]
# replyCount                                                       0
# retweetCount                                                     1
# likeCount                                                        2
# quoteCount                                                       1
# conversationId                                 1369497912284217348
# lang                                                            en
# source           <a href="http://twitter.com/download/android" ...
# sourceUrl                      http://twitter.com/download/android
# sourceLabel                                    Twitter for Android
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'ContrarianPrime', 'displayname'...
#
#                                                                  2  \
# url              https://twitter.com/PodRevDay/status/136927294...
# date                                     2021-03-09 13:04:43+00:00
# content          @sparker34621 @Podchaser @jwarnerwallace hi @s...
# renderedContent  @sparker34621 @Podchaser @jwarnerwallace hi @s...
# id                                             1369272941985341446
# user             {'username': 'PodRevDay', 'displayname': 'PodR...
# outlinks                                                        []
# tcooutlinks                                                     []
# replyCount                                                       0
# retweetCount                                                     0
# likeCount                                                        1
# quoteCount                                                       0
# conversationId                                 1369057674499928070
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'sparker34621', 'displayname': '...
#
#                                                                  3  \
# url              https://twitter.com/PodRevDay/status/136927095...
# date                                     2021-03-09 12:56:49+00:00
# content          @AtwoodPodcast @CaseyBroda @CasualBirderPod Ha...
# renderedContent  @AtwoodPodcast @CaseyBroda @CasualBirderPod Ha...
# id                                             1369270953369350146
# user             {'username': 'PodRevDay', 'displayname': 'PodR...
# outlinks                                                        []
# tcooutlinks                                                     []
# replyCount                                                       0
# retweetCount                                                     0
# likeCount                                                        2
# quoteCount                                                       0
# conversationId                                 1369147277453848584
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'AtwoodPodcast', 'displayname': ...
#
#                                                                  4
# url              https://twitter.com/PodRevDay/status/136927029...
# date                                     2021-03-09 12:54:11+00:00
# content          @Heartwarrior24 Happy you're joining us for Po...
# renderedContent  @Heartwarrior24 Happy you're joining us for Po...
# id                                             1369270290598006785
# user             {'username': 'PodRevDay', 'displayname': 'PodR...
# outlinks                                                        []
# tcooutlinks                                                     []
# replyCount                                                       0
# retweetCount                                                     0
# likeCount                                                        2
# quoteCount                                                       0
# conversationId                                 1369151391659393024
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'Heartwarrior24', 'displayname':...

# %% [markdown]
# # Get User Data

# %%
df_tweets_new.user[0]
# Out:
# {'username': 'BallsyHistory',
#  'displayname': 'Ballsy History',
#  'id': 1333248272874545153,
#  'description': 'Podcast: Take a tour of the outrageous acts, incredible stories, and outsized characters that shape history. patreon.com/ballsyhistory',
#  'rawDescription': 'Podcast: Take a tour of the outrageous acts, incredible stories, and outsized characters that shape history. https://t.co/t3ZNfYoEbe',
#  'descriptionUrls': [{'text': 'patreon.com/ballsyhistory',
#    'url': 'https://www.patreon.com/ballsyhistory',
#    'tcourl': 'https://t.co/t3ZNfYoEbe',
#    'indices': [109, 132]}],
#  'verified': False,
#  'created': '2020-11-30T03:15:57+00:00',
#  'followersCount': 428,
#  'friendsCount': 1215,
#  'statusesCount': 1182,
#  'favouritesCount': 3500,
#  'listedCount': 2,
#  'mediaCount': 53,
#  'location': '',
#  'protected': False,
#  'linkUrl': 'https://ballsyhistory.fireside.fm/',
#  'linkTcourl': 'https://t.co/8f3CNvQxjh',
#  'profileImageUrl': 'https://pbs.twimg.com/profile_images/1333248471487438848/zzDbFNTP_normal.jpg',
#  'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/1333248272874545153/1606786684',
#  'url': 'https://twitter.com/BallsyHistory'}

# %%
df_tweets_new['username'] = df_tweets_new['url'].str.split('/').str[3]

# %%
#pd.DataFrame(ser.tolist())
pod_rev_users = pd.DataFrame(df_tweets_new.user.to_list())

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                              BallsyHistory
# displayname                                          Ballsy History
# id                                              1333248272874545153
# description       Podcast: Take a tour of the outrageous acts, i...
# rawDescription    Podcast: Take a tour of the outrageous acts, i...
# descriptionUrls   [{'text': 'patreon.com/ballsyhistory', 'url': ...
# verified                                                      False
# created                                   2020-11-30T03:15:57+00:00
# followersCount                                                  428
# friendsCount                                                   1215
# statusesCount                                                  1182
# favouritesCount                                                3500
# listedCount                                                       2
# mediaCount                                                       53
# location
# protected                                                     False
# linkUrl                          https://ballsyhistory.fireside.fm/
# linkTcourl                                  https://t.co/8f3CNvQxjh
# profileImageUrl   https://pbs.twimg.com/profile_images/133324847...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/13332482...
# url                               https://twitter.com/BallsyHistory
#
#                                                                   1  \
# username                                               ODParlayHour
# displayname                           Ocho Duro Parlay Hour (#ODPH)
# id                                               861012968359817216
# description       The #ODPH podcast panel (@Odph_Ken, @Meselyn &...
# rawDescription    The #ODPH podcast panel (@Odph_Ken, @Meselyn &...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2017-05-07T00:21:03+00:00
# followersCount                                                 4442
# friendsCount                                                   3302
# statusesCount                                                 35144
# favouritesCount                                               36865
# listedCount                                                      45
# mediaCount                                                     3377
# location                                             Binghamton, NY
# protected                                                     False
# linkUrl                              https://linktr.ee/ODparlayhour
# linkTcourl                                  https://t.co/tDnTtVHHQS
# profileImageUrl   https://pbs.twimg.com/profile_images/923374528...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/86101296...
# url                                https://twitter.com/ODParlayHour
#
#                                                                   2  \
# username                                                  PodRevDay
# displayname                                               PodRevDay
# id                                              1258481717431750656
# description       Podcast Review Day,monthly Podcast Listener pa...
# rawDescription    Podcast Review Day,monthly Podcast Listener pa...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                  771
# friendsCount                                                    732
# statusesCount                                                  1743
# favouritesCount                                                1349
# listedCount                                                       4
# mediaCount                                                      245
# location                                                      World
# protected                                                     False
# linkUrl           https://archive.aweber.com/awlist5415528/LH5aF...
# linkTcourl                                  https://t.co/VTuRy4L3n2
# profileImageUrl   https://pbs.twimg.com/profile_images/126529355...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay
#
#                                                                   3  \
# username                                                  PodRevDay
# displayname                                               PodRevDay
# id                                              1258481717431750656
# description       Podcast Review Day,monthly Podcast Listener pa...
# rawDescription    Podcast Review Day,monthly Podcast Listener pa...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                  771
# friendsCount                                                    732
# statusesCount                                                  1743
# favouritesCount                                                1349
# listedCount                                                       4
# mediaCount                                                      245
# location                                                      World
# protected                                                     False
# linkUrl           https://archive.aweber.com/awlist5415528/LH5aF...
# linkTcourl                                  https://t.co/VTuRy4L3n2
# profileImageUrl   https://pbs.twimg.com/profile_images/126529355...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay
#
#                                                                   4
# username                                                  PodRevDay
# displayname                                               PodRevDay
# id                                              1258481717431750656
# description       Podcast Review Day,monthly Podcast Listener pa...
# rawDescription    Podcast Review Day,monthly Podcast Listener pa...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                  771
# friendsCount                                                    732
# statusesCount                                                  1743
# favouritesCount                                                1349
# listedCount                                                       4
# mediaCount                                                      245
# location                                                      World
# protected                                                     False
# linkUrl           https://archive.aweber.com/awlist5415528/LH5aF...
# linkTcourl                                  https://t.co/VTuRy4L3n2
# profileImageUrl   https://pbs.twimg.com/profile_images/126529355...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay

# %%
len(set(pod_rev_users.username))
# Out:
# 424

# %%
pod_rev_users = pod_rev_users.drop_duplicates(subset=['username'])

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                              BallsyHistory
# displayname                                          Ballsy History
# id                                              1333248272874545153
# description       Podcast: Take a tour of the outrageous acts, i...
# rawDescription    Podcast: Take a tour of the outrageous acts, i...
# descriptionUrls   [{'text': 'patreon.com/ballsyhistory', 'url': ...
# verified                                                      False
# created                                   2020-11-30T03:15:57+00:00
# followersCount                                                  428
# friendsCount                                                   1215
# statusesCount                                                  1182
# favouritesCount                                                3500
# listedCount                                                       2
# mediaCount                                                       53
# location
# protected                                                     False
# linkUrl                          https://ballsyhistory.fireside.fm/
# linkTcourl                                  https://t.co/8f3CNvQxjh
# profileImageUrl   https://pbs.twimg.com/profile_images/133324847...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/13332482...
# url                               https://twitter.com/BallsyHistory
#
#                                                                   1  \
# username                                               ODParlayHour
# displayname                           Ocho Duro Parlay Hour (#ODPH)
# id                                               861012968359817216
# description       The #ODPH podcast panel (@Odph_Ken, @Meselyn &...
# rawDescription    The #ODPH podcast panel (@Odph_Ken, @Meselyn &...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2017-05-07T00:21:03+00:00
# followersCount                                                 4442
# friendsCount                                                   3302
# statusesCount                                                 35144
# favouritesCount                                               36865
# listedCount                                                      45
# mediaCount                                                     3377
# location                                             Binghamton, NY
# protected                                                     False
# linkUrl                              https://linktr.ee/ODparlayhour
# linkTcourl                                  https://t.co/tDnTtVHHQS
# profileImageUrl   https://pbs.twimg.com/profile_images/923374528...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/86101296...
# url                                https://twitter.com/ODParlayHour
#
#                                                                   2  \
# username                                                  PodRevDay
# displayname                                               PodRevDay
# id                                              1258481717431750656
# description       Podcast Review Day,monthly Podcast Listener pa...
# rawDescription    Podcast Review Day,monthly Podcast Listener pa...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                  771
# friendsCount                                                    732
# statusesCount                                                  1743
# favouritesCount                                                1349
# listedCount                                                       4
# mediaCount                                                      245
# location                                                      World
# protected                                                     False
# linkUrl           https://archive.aweber.com/awlist5415528/LH5aF...
# linkTcourl                                  https://t.co/VTuRy4L3n2
# profileImageUrl   https://pbs.twimg.com/profile_images/126529355...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay
#
#                                                                   5  \
# username                                              OnceUponAGene
# displayname                                             Effie Parks
# id                                              1059513315376869378
# description       Podcast Host🎤\n Helping to share stories and r...
# rawDescription    Podcast Host🎤\n Helping to share stories and r...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2018-11-05T18:30:34+00:00
# followersCount                                                  724
# friendsCount                                                   1446
# statusesCount                                                  1669
# favouritesCount                                                3430
# listedCount                                                       0
# mediaCount                                                      248
# location                                                Seattle, WA
# protected                                                     False
# linkUrl                              https://effieparks.com/podcast
# linkTcourl                                  https://t.co/Cp6vEyNLBK
# profileImageUrl   https://pbs.twimg.com/profile_images/118966596...
# profileBannerUrl                                               None
# url                               https://twitter.com/OnceUponAGene
#
#                                                                   6
# username                                               OracleofDusk
# displayname                                               MJ Bailey
# id                                              1087100443761758208
# description       the story of a reluctant oracle. and maybe... ...
# rawDescription    the story of a reluctant oracle. and maybe... ...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2019-01-20T21:31:57+00:00
# followersCount                                                  800
# friendsCount                                                   1789
# statusesCount                                                  2290
# favouritesCount                                                3688
# listedCount                                                       8
# mediaCount                                                      284
# location
# protected                                                     False
# linkUrl                                  http://oracleofdusk.online
# linkTcourl                                  https://t.co/sTfHhVd0AQ
# profileImageUrl   https://pbs.twimg.com/profile_images/134159538...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/10871004...
# url                                https://twitter.com/OracleofDusk

# %%
pod_rev_users.shape
# Out:
# (424, 21)

# %% [markdown]
# # Clean User Data

# %%
df_users = pod_rev_users.loc[:, ['id','username', 'displayname', 'location', 'created', 'followersCount', 'friendsCount', 'url', 'verified' ]]

# %%
def location_extraction (df):
    '''Creates creates a geotext column to extract city and country info if possible'''

    df.loc[:, "location"] = df.loc[:, "location"].fillna("blank")
    df.loc[:, "geotext"] = df.loc[:, "location"].apply(GeoText)
    df.loc[:, 'city'] = df.loc[:, 'geotext'].apply(lambda x: x.cities)
    df.loc[:, 'country'] = df.loc[:, 'geotext'].apply(lambda x: x.countries)
    
    return df

df_users = location_extraction(df_users)

# %%
from geonamescache import GeonamesCache
gc = GeonamesCache()
countries = gc.get_countries()
country_info = pd.DataFrame(countries).T
country_info = country_info.set_index('geonameid').reset_index()
name_code = country_info.loc[:, ["name", "iso3"]]

us_states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
             "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA",
             "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY",
             "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX",
             "UT", "VT", "VA", "WA", "WV", "WI", "WY", "USA", "United States",
             'Seattle', "Los Angeles", "Houston", "Atlanta", "Pittsburgh"]

us_state_names = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", 
               "District ", "of Columbia", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", 
               "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", 
               "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", 
               "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", 
               "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", 
               "Wisconsin", "West Virginia", "Wyoming"]

can_prov_abbrev = {'Alberta': 'AB','British Columbia': 'BC','Manitoba': 'MB', 'New Brunswick': 'NB',
                       'Newfoundland and Labrador': 'NL', 'Northwest Territories': 'NT','Nova Scotia': 'NS','Nunavut': 'NU',
                       'Ontario': 'ON','Prince Edward Island': 'PE', 'Quebec': 'QC','Saskatchewan': 'SK','Yukon': 'YT'}

can_prov_names, can_prov_abbr = zip(*can_prov_abbrev.items())

uk = ["England", 'Wales', "Scotland", 'London', "Manchester", "Isle of Wight", "Northern Ireland", "United Kingdom", 'Bailiwick of Guernsey', "UK", "Hoxton", "Jersey"]

india_city = ["Bangalore", "Delhi", "Hyderabad", "Bengaluru"]

german_city = ["Munich", "Berlin", "eisgau","Hamburg", "Dortmund"]

south_africa = ["South Africa", "Durban", "Johannesburg"]

uae = ['UAE', 'Dubai', 'Abu Dhabi']

def replacer(area, name):
    df_users.loc[(df_users.location.str.contains('|'.join(area))), "country"] = name    
    return df_users

def list_to_string(df):
    df["city"] = df['city'].apply(lambda x: "".join(map(str, x)))
    df["country"] = df['country'].apply(lambda x: "".join(map(str, x)))
    
    return df

# %%
def location_cleaner(df):
    df = replacer(can_prov_names, "Canada")
    df = replacer(can_prov_abbrev, "Canada")
    df = replacer(us_state_names, "United States")
    df = replacer(us_states, "United States")
    df = replacer(uk, "United Kingdom")
    df = replacer(german_city, "Germany")
    df = replacer(south_africa, "South Africa")
    df = replacer(india_city, "India")
    df = replacer(uae, 'United Arab Emirates')
    df.loc[(df.location == "Italia"), "country"] = "Italy" 
    df.loc[(df.location == "Belgrade"), "country"] = "Serbia" 
    df.loc[(df.country == "PolandSerbia"), "country"] = "Poland" 
    df = list_to_string(df)
    
    return df

# %%
df_users = location_cleaner(df_users)
df_users.loc[(df_users.country == "PolandSerbia"), "country"] = "Poland"

# %%
df_users.country.value_counts()
# Out:
#                         184
# United States           151
# United Kingdom           41
# Canada                   20
# Germany                   5
# Australia                 3
# India                     3
# Poland                    3
# Spain                     2
# Italy                     1
# Albania                   1
# Ecuador                   1
# Vietnam                   1
# Sweden                    1
# Malaysia                  1
# Vanuatu                   1
# New Zealand               1
# France                    1
# Ireland                   1
# Nigeria                   1
# United Arab Emirates      1
# Name: country, dtype: int64

# %%
df_users_full = pd.merge(left=df_users,
                    right=name_code,
                    how='left',
                    left_on='country',
                    right_on='name')

# %%
df_users_full.head()
# Out:
#                     id       username                    displayname  \
# 0  1333248272874545153  BallsyHistory                 Ballsy History
# 1   861012968359817216   ODParlayHour  Ocho Duro Parlay Hour (#ODPH)
# 2  1258481717431750656      PodRevDay                      PodRevDay
# 3  1059513315376869378  OnceUponAGene                    Effie Parks
# 4  1087100443761758208   OracleofDusk                      MJ Bailey
#
#          location                    created  followersCount  friendsCount  \
# 0                  2020-11-30T03:15:57+00:00             428          1215
# 1  Binghamton, NY  2017-05-07T00:21:03+00:00            4442          3302
# 2           World  2020-05-07T19:40:12+00:00             771           732
# 3     Seattle, WA  2018-11-05T18:30:34+00:00             724          1446
# 4                  2019-01-20T21:31:57+00:00             800          1789
#
#                                  url  verified  \
# 0  https://twitter.com/BallsyHistory     False
# 1   https://twitter.com/ODParlayHour     False
# 2      https://twitter.com/PodRevDay     False
# 3  https://twitter.com/OnceUponAGene     False
# 4   https://twitter.com/OracleofDusk     False
#
#                                              geotext        city  \
# 0  <geotext.geotext.GeoText object at 0x7f8b86071...
# 1  <geotext.geotext.GeoText object at 0x7f8b86071...  Binghamton
# 2  <geotext.geotext.GeoText object at 0x7f8b86071...
# 3  <geotext.geotext.GeoText object at 0x7f8b86071...     Seattle
# 4  <geotext.geotext.GeoText object at 0x7f8b86071...
#
#          country           name iso3
# 0                           NaN  NaN
# 1  United States  United States  USA
# 2                           NaN  NaN
# 3  United States  United States  USA
# 4                           NaN  NaN

# %% [markdown]
# ## Update Followers Data

# %%
df_users.to_csv('data/user_data.csv')

# %% [markdown]
# # Merge User's Geographic Data with Tweets

# %%
full_df = pd.merge(left=df_tweets_new, 
                   right=df_users_full, 
                   how='left',
                   on='username')

full_df.to_csv('data/tweets_users_march_21.csv', index=False)
