# %% [markdown]
# # Get All Tweets with #PodRevDay

# %%
# Get the data
# !snscrape --jsonl twitter-hashtag "#podrevday since:2020-01-01 until:2021-06-12" > 'data/jan20_jun21.json'

# %%
import pandas as pd
from geotext import GeoText

df_tweets_old = pd.read_json('data/jan20_may21.json', lines=True)
df_tweets_new = pd.read_json('data/jan20_jun21.json', lines=True)

# %%
print(df_tweets_old.shape)
print(df_tweets_new.shape)
print(f'Number of tweets last month useing #podrevday: {df_tweets_new.shape[0] - df_tweets_old.shape[0]}')
# Out:
# (2187, 21)
# (2452, 21)
# Number of tweets last month useing #podrevday: 265

# %%
df_tweets_new.head().T
# Out:
#                                                                  0  \
# url              https://twitter.com/PodRevDay/status/140297404...
# date                                     2021-06-10 13:00:52+00:00
# content          Thanks to @amarksteadman for the #podrevday me...
# renderedContent  Thanks to @amarksteadman for the #podrevday me...
# id                                             1402974042685153281
# user             {'username': 'PodRevDay', 'displayname': 'Podc...
# outlinks                                                        []
# tcooutlinks                                                     []
# replyCount                                                       0
# retweetCount                                                     2
# likeCount                                                        5
# quoteCount                                                       0
# conversationId                                 1402974042685153281
# lang                                                            en
# source           <a href="http://twitter.com/download/android" ...
# sourceUrl                      http://twitter.com/download/android
# sourceLabel                                    Twitter for Android
# media            [{'previewUrl': 'https://pbs.twimg.com/media/E...
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'amarksteadman', 'displayname': ...
#
#                                                                  1  \
# url              https://twitter.com/realnealveglio/status/1402...
# date                                     2021-06-10 12:15:25+00:00
# content          @JamesBurtt @Podchaser Keep it up, Mr Burtt! @...
# renderedContent  @JamesBurtt @Podchaser Keep it up, Mr Burtt! @...
# id                                             1402962603358498829
# user             {'username': 'realnealveglio', 'displayname': ...
# outlinks                                                        []
# tcooutlinks                                                     []
# replyCount                                                       0
# retweetCount                                                     0
# likeCount                                                        0
# quoteCount                                                       0
# conversationId                                 1402896647986855941
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'JamesBurtt', 'displayname': 'ja...
#
#                                                                  2  \
# url              https://twitter.com/talkin_shiz/status/1402953...
# date                                     2021-06-10 11:41:01+00:00
# content          If you looking for a great podcast check us ou...
# renderedContent  If you looking for a great podcast check us ou...
# id                                             1402953946050842628
# user             {'username': 'talkin_shiz', 'displayname': 'Ta...
# outlinks         [https://www.podchaser.com/podcasts/talkin-shi...
# tcooutlinks                              [https://t.co/xbbHiiYmJF]
# replyCount                                                       0
# retweetCount                                                     0
# likeCount                                                        1
# quoteCount                                                       0
# conversationId                                 1402953946050842628
# lang                                                            en
# source           <a href="http://twitter.com/download/iphone" r...
# sourceUrl                       http://twitter.com/download/iphone
# sourceLabel                                     Twitter for iPhone
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'Podchaser', 'displayname': 'Pod...
#
#                                                                  3  \
# url              https://twitter.com/WomenOnMic/status/14027447...
# date                                     2021-06-09 21:49:56+00:00
# content          Huge thank you to @stephfuccio for sharing the...
# renderedContent  Huge thank you to @stephfuccio for sharing the...
# id                                             1402744798650376193
# user             {'username': 'WomenOnMic', 'displayname': 'Wom...
# outlinks                                                        []
# tcooutlinks                                                     []
# replyCount                                                       2
# retweetCount                                                     4
# likeCount                                                        8
# quoteCount                                                       0
# conversationId                                 1402744798650376193
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'stephfuccio', 'displayname': 'S...
#
#                                                                  4
# url              https://twitter.com/LsceP/status/1402734266597...
# date                                     2021-06-09 21:08:05+00:00
# content          A little belated for #PodRevDay but Check out ...
# renderedContent  A little belated for #PodRevDay but Check out ...
# id                                             1402734266597974018
# user             {'username': 'LsceP', 'displayname': 'I Saw It...
# outlinks         [https://www.podchaser.com/podcasts/dads-on-da...
# tcooutlinks                              [https://t.co/3pnbdGms2O]
# replyCount                                                       0
# retweetCount                                                     0
# likeCount                                                        0
# quoteCount                                                       1
# conversationId                                 1402734266597974018
# lang                                                            en
# source           <a href="http://twitter.com/download/iphone" r...
# sourceUrl                       http://twitter.com/download/iphone
# sourceLabel                                     Twitter for iPhone
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'Podchaser', 'displayname': 'Pod...

# %% [markdown]
# # Get User Data

# %%
# for i in range(len(df_tweets_new['user'])):
#     print(df_tweets_new['user'][i]["username"])

# %%
df_tweets_new.user[0]
# Out:
# {'username': 'PodRevDay',
#  'displayname': 'Podcast Review Day, #podrevday',
#  'id': 1258481717431750656,
#  'description': 'We connect Podcasters AND Listeners on 8th every month on the #podrevday hashtag. Newsletter, podcast, & YouTube also. @stephfuccio\n#podcastrecommendations',
#  'rawDescription': 'We connect Podcasters AND Listeners on 8th every month on the #podrevday hashtag. Newsletter, podcast, & YouTube also. @stephfuccio\n#podcastrecommendations',
#  'descriptionUrls': [],
#  'verified': False,
#  'created': '2020-05-07T19:40:12+00:00',
#  'followersCount': 1020,
#  'friendsCount': 1141,
#  'statusesCount': 3033,
#  'favouritesCount': 2213,
#  'listedCount': 6,
#  'mediaCount': 428,
#  'location': '',
#  'protected': False,
#  'linkUrl': 'http://www.podrevday.com',
#  'linkTcourl': 'https://t.co/lc8oz6UEQv',
#  'profileImageUrl': 'https://pbs.twimg.com/profile_images/1402695798865997824/H8z0AGtj_normal.jpg',
#  'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/1258481717431750656/1622019963',
#  'url': 'https://twitter.com/PodRevDay'}

# %%
df_tweets_new['username'] = df_tweets_new['url'].str.split('/').str[3]

# %%
#pd.DataFrame(ser.tolist())
pod_rev_users = pd.DataFrame(df_tweets_new.user.to_list())

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                                  PodRevDay
# displayname                          Podcast Review Day, #podrevday
# id                                              1258481717431750656
# description       We connect Podcasters AND Listeners on 8th eve...
# rawDescription    We connect Podcasters AND Listeners on 8th eve...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                 1020
# friendsCount                                                   1141
# statusesCount                                                  3033
# favouritesCount                                                2213
# listedCount                                                       6
# mediaCount                                                      428
# location
# protected                                                     False
# linkUrl                                    http://www.podrevday.com
# linkTcourl                                  https://t.co/lc8oz6UEQv
# profileImageUrl   https://pbs.twimg.com/profile_images/140269579...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay
#
#                                                                   1  \
# username                                             realnealveglio
# displayname                                             Neal Veglio
# id                                                       4056011122
# description       Proud 2021 British Podcast Awards judge. \nFou...
# rawDescription    Proud 2021 British Podcast Awards judge. \nFou...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2015-10-27T20:56:00+00:00
# followersCount                                                 3364
# friendsCount                                                   2704
# statusesCount                                                 17462
# favouritesCount                                               18296
# listedCount                                                      43
# mediaCount                                                     1464
# location                                            Oxford, England
# protected                                                     False
# linkUrl                         http://www.podknowspodcasting.co.uk
# linkTcourl                                  https://t.co/cIETh2qShJ
# profileImageUrl   https://pbs.twimg.com/profile_images/137212458...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/40560111...
# url                              https://twitter.com/realnealveglio
#
#                                                                   2  \
# username                                                talkin_shiz
# displayname                                            Talkin’ Shiz
# id                                              1215116557946380289
# description       Twipods Best Comedy Award Winner! 🏆 Our podcas...
# rawDescription    Twipods Best Comedy Award Winner! 🏆 Our podcas...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-01-09T03:42:27+00:00
# followersCount                                                 5102
# friendsCount                                                   2757
# statusesCount                                                 20494
# favouritesCount                                               35629
# listedCount                                                      46
# mediaCount                                                    11046
# location                                             Tennessee, USA
# protected                                                     False
# linkUrl                 https://www.podpage.com/talkin-shiz/listen/
# linkTcourl                                  https://t.co/u80GjBIwwu
# profileImageUrl   https://pbs.twimg.com/profile_images/134766592...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12151165...
# url                                 https://twitter.com/talkin_shiz
#
#                                                                   3  \
# username                                                 WomenOnMic
# displayname                                            Women On Mic
# id                                              1397759262500085761
# description       Founded by @IAmJust_Heather 🎤 Creating an audi...
# rawDescription    Founded by @IAmJust_Heather 🎤 Creating an audi...
# descriptionUrls   [{'text': 'womenonmic.org', 'url': 'https://wo...
# verified                                                      False
# created                                   2021-05-27T03:39:27+00:00
# followersCount                                                   33
# friendsCount                                                     67
# statusesCount                                                    29
# favouritesCount                                                  47
# listedCount                                                       0
# mediaCount                                                        7
# location                                                  Worldwide
# protected                                                     False
# linkUrl                         https://forms.gle/UHR5nsmztC6J7VT38
# linkTcourl                                  https://t.co/7AMwsGmB4H
# profileImageUrl   https://pbs.twimg.com/profile_images/139775958...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/13977592...
# url                                  https://twitter.com/WomenOnMic
#
#                                                                   4
# username                                                      LsceP
# displayname                               I Saw It On Linden Street
# id                                              1152104357523021825
# description       “I Saw It On Linden Street” is dedicated to th...
# rawDescription    “I Saw It On Linden Street” is dedicated to th...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2019-07-19T06:34:18+00:00
# followersCount                                                  654
# friendsCount                                                   1015
# statusesCount                                                  2719
# favouritesCount                                                2864
# listedCount                                                       4
# mediaCount                                                      277
# location                                                 Normal, IL
# protected                                                     False
# linkUrl                                            http://lscep.com
# linkTcourl                                  https://t.co/tOWwn4IejZ
# profileImageUrl   https://pbs.twimg.com/profile_images/115310778...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/11521043...
# url                                       https://twitter.com/LsceP

# %%
len(set(pod_rev_users.username))
# Out:
# 504

# %%
pod_rev_users = pod_rev_users.drop_duplicates(subset=['username'])

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                                  PodRevDay
# displayname                          Podcast Review Day, #podrevday
# id                                              1258481717431750656
# description       We connect Podcasters AND Listeners on 8th eve...
# rawDescription    We connect Podcasters AND Listeners on 8th eve...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                 1020
# friendsCount                                                   1141
# statusesCount                                                  3033
# favouritesCount                                                2213
# listedCount                                                       6
# mediaCount                                                      428
# location
# protected                                                     False
# linkUrl                                    http://www.podrevday.com
# linkTcourl                                  https://t.co/lc8oz6UEQv
# profileImageUrl   https://pbs.twimg.com/profile_images/140269579...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay
#
#                                                                   1  \
# username                                             realnealveglio
# displayname                                             Neal Veglio
# id                                                       4056011122
# description       Proud 2021 British Podcast Awards judge. \nFou...
# rawDescription    Proud 2021 British Podcast Awards judge. \nFou...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2015-10-27T20:56:00+00:00
# followersCount                                                 3364
# friendsCount                                                   2704
# statusesCount                                                 17462
# favouritesCount                                               18296
# listedCount                                                      43
# mediaCount                                                     1464
# location                                            Oxford, England
# protected                                                     False
# linkUrl                         http://www.podknowspodcasting.co.uk
# linkTcourl                                  https://t.co/cIETh2qShJ
# profileImageUrl   https://pbs.twimg.com/profile_images/137212458...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/40560111...
# url                              https://twitter.com/realnealveglio
#
#                                                                   2  \
# username                                                talkin_shiz
# displayname                                            Talkin’ Shiz
# id                                              1215116557946380289
# description       Twipods Best Comedy Award Winner! 🏆 Our podcas...
# rawDescription    Twipods Best Comedy Award Winner! 🏆 Our podcas...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-01-09T03:42:27+00:00
# followersCount                                                 5102
# friendsCount                                                   2757
# statusesCount                                                 20494
# favouritesCount                                               35629
# listedCount                                                      46
# mediaCount                                                    11046
# location                                             Tennessee, USA
# protected                                                     False
# linkUrl                 https://www.podpage.com/talkin-shiz/listen/
# linkTcourl                                  https://t.co/u80GjBIwwu
# profileImageUrl   https://pbs.twimg.com/profile_images/134766592...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12151165...
# url                                 https://twitter.com/talkin_shiz
#
#                                                                   3  \
# username                                                 WomenOnMic
# displayname                                            Women On Mic
# id                                              1397759262500085761
# description       Founded by @IAmJust_Heather 🎤 Creating an audi...
# rawDescription    Founded by @IAmJust_Heather 🎤 Creating an audi...
# descriptionUrls   [{'text': 'womenonmic.org', 'url': 'https://wo...
# verified                                                      False
# created                                   2021-05-27T03:39:27+00:00
# followersCount                                                   33
# friendsCount                                                     67
# statusesCount                                                    29
# favouritesCount                                                  47
# listedCount                                                       0
# mediaCount                                                        7
# location                                                  Worldwide
# protected                                                     False
# linkUrl                         https://forms.gle/UHR5nsmztC6J7VT38
# linkTcourl                                  https://t.co/7AMwsGmB4H
# profileImageUrl   https://pbs.twimg.com/profile_images/139775958...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/13977592...
# url                                  https://twitter.com/WomenOnMic
#
#                                                                   4
# username                                                      LsceP
# displayname                               I Saw It On Linden Street
# id                                              1152104357523021825
# description       “I Saw It On Linden Street” is dedicated to th...
# rawDescription    “I Saw It On Linden Street” is dedicated to th...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2019-07-19T06:34:18+00:00
# followersCount                                                  654
# friendsCount                                                   1015
# statusesCount                                                  2719
# favouritesCount                                                2864
# listedCount                                                       4
# mediaCount                                                      277
# location                                                 Normal, IL
# protected                                                     False
# linkUrl                                            http://lscep.com
# linkTcourl                                  https://t.co/tOWwn4IejZ
# profileImageUrl   https://pbs.twimg.com/profile_images/115310778...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/11521043...
# url                                       https://twitter.com/LsceP

# %%
pod_rev_users.shape
# Out:
# (504, 21)

# %% [markdown]
# # Clean User Data

# %%
df_users = pod_rev_users.loc[:, ['id','username', 'displayname', 'location', 'created', 'followersCount', 'friendsCount', 'url', 'verified' ]]

# %%
def location_extraction (df):
    '''Creates creates a geotext column to extract city and country info if possible'''

    df.loc[:, "location"] = df.loc[:, "location"].fillna("blank")
    df.loc[:, "geotext"] = df.loc[:, "location"].apply(GeoText)
    df.loc[:, 'city'] = df.loc[:, 'geotext'].apply(lambda x: x.cities)
    df.loc[:, 'country'] = df.loc[:, 'geotext'].apply(lambda x: x.countries)
    
    return df

df_users = location_extraction(df_users)

# %%
from geonamescache import GeonamesCache
gc = GeonamesCache()
countries = gc.get_countries()
country_info = pd.DataFrame(countries).T
country_info = country_info.set_index('geonameid').reset_index()
name_code = country_info.loc[:, ["name", "iso3"]]

us_states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
             "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA",
             "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY",
             "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX",
             "UT", "VT", "VA", "WA", "WV", "WI", "WY", "USA", "United States",
             'Seattle', "Los Angeles", "Houston", "Atlanta", "Pittsburgh"]

us_state_names = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", 
               "District ", "of Columbia", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", 
               "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", 
               "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", 
               "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", 
               "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", 
               "Wisconsin", "West Virginia", "Wyoming"]

can_prov_abbrev = {'Alberta': 'AB','British Columbia': 'BC','Manitoba': 'MB', 'New Brunswick': 'NB',
                       'Newfoundland and Labrador': 'NL', 'Northwest Territories': 'NT','Nova Scotia': 'NS','Nunavut': 'NU',
                       'Ontario': 'ON','Prince Edward Island': 'PE', 'Quebec': 'QC','Saskatchewan': 'SK','Yukon': 'YT'}

can_prov_names, can_prov_abbr = zip(*can_prov_abbrev.items())

uk = ["England", 'Wales', "Scotland", 'London', "Manchester", "Isle of Wight", "Northern Ireland", "United Kingdom", 'Bailiwick of Guernsey', "UK", "Hoxton", "Jersey"]

india_city = ["Bangalore", "Delhi", "Hyderabad", "Bengaluru"]

german_city = ["Munich", "Berlin", "eisgau","Hamburg", "Dortmund"]

south_africa = ["South Africa", "Durban", "Johannesburg"]

south_korea = ["Republic of Korea"]

uae = ['UAE', 'Dubai', 'Abu Dhabi']


def replacer(area, name):
    df_users.loc[(df_users.location.str.contains('|'.join(area))), "country"] = name    
    return df_users

def list_to_string(df):
    df["city"] = df['city'].apply(lambda x: "".join(map(str, x)))
    df["country"] = df['country'].apply(lambda x: "".join(map(str, x)))
    
    return df

# %%
def location_cleaner(df):
    df = replacer(can_prov_names, "Canada")
    df = replacer(can_prov_abbrev, "Canada")
    df = replacer(us_state_names, "United States")
    df = replacer(us_states, "United States")
    df = replacer(uk, "United Kingdom")
    df = replacer(german_city, "Germany")
    df = replacer(south_africa, "South Africa")
    df = replacer(india_city, "India")
    df = replacer(uae, 'United Arab Emirates')
    df = replacer(south_korea, "South Korea")
    df.loc[(df.location == "Italia"), "country"] = "Italy" 
    df.loc[(df.location == "Belgrade"), "country"] = "Serbia" 
    df.loc[(df.country == "PolandSerbia"), "country"] = "Poland" 
    df = list_to_string(df)
    
    return df

# %%
df_users = location_cleaner(df_users)
df_users.loc[(df_users.country == "PolandSerbia"), "country"] = "Poland"

# %%
df_users.country.value_counts()
# Out:
#                         226
# United States           172
# United Kingdom           47
# Canada                   24
# Germany                   6
# Australia                 3
# Ireland                   3
# Poland                    3
# India                     3
# Spain                     3
# France                    2
# Nigeria                   2
# New Zealand               2
# Malaysia                  2
# Italy                     1
# Sweden                    1
# Ecuador                   1
# United Arab Emirates      1
# Vanuatu                   1
# South Korea               1
# Name: country, dtype: int64

# %%
df_users_full = pd.merge(left=df_users,
                    right=name_code,
                    how='left',
                    left_on='country',
                    right_on='name')

# %%
df_users_full.head()
# Out:
#                     id        username                     displayname  \
# 0  1258481717431750656       PodRevDay  Podcast Review Day, #podrevday
# 1           4056011122  realnealveglio                     Neal Veglio
# 2  1215116557946380289     talkin_shiz                    Talkin’ Shiz
# 3  1397759262500085761      WomenOnMic                    Women On Mic
# 4  1152104357523021825           LsceP       I Saw It On Linden Street
#
#           location                    created  followersCount  friendsCount  \
# 0                   2020-05-07T19:40:12+00:00            1020          1141
# 1  Oxford, England  2015-10-27T20:56:00+00:00            3364          2704
# 2   Tennessee, USA  2020-01-09T03:42:27+00:00            5102          2757
# 3        Worldwide  2021-05-27T03:39:27+00:00              33            67
# 4       Normal, IL  2019-07-19T06:34:18+00:00             654          1015
#
#                                   url  verified  \
# 0       https://twitter.com/PodRevDay     False
# 1  https://twitter.com/realnealveglio     False
# 2     https://twitter.com/talkin_shiz     False
# 3      https://twitter.com/WomenOnMic     False
# 4           https://twitter.com/LsceP     False
#
#                                              geotext    city         country  \
# 0  <geotext.geotext.GeoText object at 0x7f4bdcca4...
# 1  <geotext.geotext.GeoText object at 0x7f4bdcca4...  Oxford  United Kingdom
# 2  <geotext.geotext.GeoText object at 0x7f4bdcca4...           United States
# 3  <geotext.geotext.GeoText object at 0x7f4bdcca4...
# 4  <geotext.geotext.GeoText object at 0x7f4bdcca4...  Normal   United States
#
#              name iso3
# 0             NaN  NaN
# 1  United Kingdom  GBR
# 2   United States  USA
# 3             NaN  NaN
# 4   United States  USA

# %% [markdown]
# ## Update Followers Data

# %%
df_users.to_csv('data/user_data.csv')

# %% [markdown]
# # Merge User's Geographic Data with Tweets

# %%
full_df = pd.merge(left=df_tweets_new, 
                   right=df_users_full, 
                   how='left',
                   on='username')

full_df.to_csv('data/tweets_users_jun_21.csv', index=False)

# %%
full_df.shape
# Out:
# (2452, 35)
