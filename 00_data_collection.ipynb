# %% [markdown]
# # Get All Tweets with #PodRevDay

# %%
# Get the data
# !snscrape --jsonl twitter-hashtag "#podrevday since:2020-01-01 until:2021-02-13" > 'data/jan20_feb_21.json'

# %%
import pandas as pd
from geotext import GeoText

df_tweets_old = pd.read_json('data/jan-jan-2021.json', lines=True)
df_tweets_new = pd.read_json('data/jan20_feb_21.json', lines=True)

# %%
print(df_tweets_old.shape)
print(df_tweets_new.shape)
# Out:
# (1530, 21)
# (1729, 21)

# %%
df_tweets_new.head().T
# Out:
#                                                                  0  \
# url              https://twitter.com/LaydenRobinson/status/1360...
# date                                     2021-02-12 03:22:52+00:00
# content          Check out and listen to @AlanMcGill14 awesome,...
# renderedContent  Check out and listen to @AlanMcGill14 awesome,...
# id                                             1360066816240881668
# user             {'username': 'LaydenRobinson', 'displayname': ...
# outlinks                 [https://cryinthemoonslight.podbean.com/]
# tcooutlinks                              [https://t.co/BUhTwtMtpw]
# replyCount                                                       0
# retweetCount                                                     1
# likeCount                                                        1
# quoteCount                                                       0
# conversationId                                 1360066816240881668
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media            [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'AlanMcGill14', 'displayname': '...
#
#                                                                  1  \
# url              https://twitter.com/LizWilcox79/status/1359270...
# date                                     2021-02-09 22:37:19+00:00
# content          "How's February treating you so far?" you ask....
# renderedContent  "How's February treating you so far?" you ask....
# id                                             1359270180212232192
# user             {'username': 'LizWilcox79', 'displayname': 'El...
# outlinks                                                        []
# tcooutlinks                                                     []
# replyCount                                                       1
# retweetCount                                                     0
# likeCount                                                        2
# quoteCount                                                       0
# conversationId                                 1359270180212232192
# lang                                                            en
# source           <a href="http://twitter.com/download/android" ...
# sourceUrl                      http://twitter.com/download/android
# sourceLabel                                    Twitter for Android
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers                                                None
#
#                                                                  2  \
# url              https://twitter.com/PodRevDay/status/135915938...
# date                                     2021-02-09 15:17:04+00:00
# content          You can get #podrevday reminders and info in y...
# renderedContent  You can get #podrevday reminders and info in y...
# id                                             1359159386489425932
# user             {'username': 'PodRevDay', 'displayname': 'PodR...
# outlinks                                [http://www.podrevday.com]
# tcooutlinks                              [https://t.co/oet2vmUjAb]
# replyCount                                                       0
# retweetCount                                                     2
# likeCount                                                        1
# quoteCount                                                       0
# conversationId                                 1359159386489425932
# lang                                                            en
# source           <a href="http://twitter.com/download/android" ...
# sourceUrl                      http://twitter.com/download/android
# sourceLabel                                    Twitter for Android
# media            [{'previewUrl': 'https://pbs.twimg.com/media/E...
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers                                                None
#
#                                                                  3  \
# url              https://twitter.com/KidsWatching/status/135907...
# date                                     2021-02-09 09:58:08+00:00
# content          #podrevday - love these guys, loved their take...
# renderedContent  #podrevday - love these guys, loved their take...
# id                                             1359079124292276224
# user             {'username': 'KidsWatching', 'displayname': 'K...
# outlinks                                                        []
# tcooutlinks                                                     []
# replyCount                                                       0
# retweetCount                                                     1
# likeCount                                                        5
# quoteCount                                                       1
# conversationId                                 1359079124292276224
# lang                                                            en
# source           <a href="http://twitter.com/download/android" ...
# sourceUrl                      http://twitter.com/download/android
# sourceLabel                                    Twitter for Android
# media            [{'previewUrl': 'https://pbs.twimg.com/media/E...
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'Straight2DVDPod', 'displayname'...
#
#                                                                  4
# url              https://twitter.com/PodRevDay/status/135907664...
# date                                     2021-02-09 09:48:17+00:00
# content          wow #podrevday yesterday was unreal!\n\nWill r...
# renderedContent  wow #podrevday yesterday was unreal!\n\nWill r...
# id                                             1359076645492166659
# user             {'username': 'PodRevDay', 'displayname': 'PodR...
# outlinks                                [http://www.podrevday.com]
# tcooutlinks                              [https://t.co/oet2vmUjAb]
# replyCount                                                       0
# retweetCount                                                     0
# likeCount                                                        0
# quoteCount                                                       0
# conversationId                                 1359076645492166659
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media            [{'previewUrl': 'https://pbs.twimg.com/media/E...
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers                                                None

# %% [markdown]
# # Get User Data

# %%
df_tweets_new.user[0]
# Out:
# {'username': 'LaydenRobinson',
#  'displayname': 'Layden Robinson',
#  'id': 42290868,
#  'description': '"Don\'t ever be ashamed of your story.  Somewhere there is someone who will be inspired by it."\nContact for Social Media Assistance: robinsonderek@hotmail.com',
#  'rawDescription': '"Don\'t ever be ashamed of your story.  Somewhere there is someone who will be inspired by it."\nContact for Social Media Assistance: robinsonderek@hotmail.com',
#  'descriptionUrls': [],
#  'verified': False,
#  'created': '2009-05-24T22:04:27+00:00',
#  'followersCount': 82326,
#  'friendsCount': 90220,
#  'statusesCount': 689046,
#  'favouritesCount': 123045,
#  'listedCount': 1711,
#  'mediaCount': 283832,
#  'location': 'San Diego, CA',
#  'protected': False,
#  'linkUrl': 'https://laydenrobinson.bandcamp.com/album/artists-for-matilda',
#  'linkTcourl': 'https://t.co/LEo8TazGhI',
#  'profileImageUrl': 'https://pbs.twimg.com/profile_images/917740321194180608/XS0wVN4a_normal.jpg',
#  'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/42290868/1507641345',
#  'url': 'https://twitter.com/LaydenRobinson'}

# %%
df_tweets_new['username'] = df_tweets_new['url'].str.split('/').str[3]

# %%
#pd.DataFrame(ser.tolist())
pod_rev_users = pd.DataFrame(df_tweets_new.user.to_list())

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                             LaydenRobinson
# displayname                                         Layden Robinson
# id                                                         42290868
# description       "Don't ever be ashamed of your story.  Somewhe...
# rawDescription    "Don't ever be ashamed of your story.  Somewhe...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2009-05-24T22:04:27+00:00
# followersCount                                                82326
# friendsCount                                                  90220
# statusesCount                                                689046
# favouritesCount                                              123045
# listedCount                                                    1711
# mediaCount                                                   283832
# location                                              San Diego, CA
# protected                                                     False
# linkUrl           https://laydenrobinson.bandcamp.com/album/arti...
# linkTcourl                                  https://t.co/LEo8TazGhI
# profileImageUrl   https://pbs.twimg.com/profile_images/917740321...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/42290868...
# url                              https://twitter.com/LaydenRobinson
#
#                                                                   1  \
# username                                                LizWilcox79
# displayname                                        Elizabeth Wilcox
# id                                               788584258826665984
# description       Writer, Avid Role-Player, Amateur Mixologist, ...
# rawDescription    Writer, Avid Role-Player, Amateur Mixologist, ...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2016-10-19T03:35:13+00:00
# followersCount                                                  314
# friendsCount                                                    457
# statusesCount                                                  1686
# favouritesCount                                               11108
# listedCount                                                       0
# mediaCount                                                      228
# location                                                  Tempe, AZ
# protected                                                     False
# linkUrl                              https://www.briarbooklane.com/
# linkTcourl                                  https://t.co/FmtWS2qcaY
# profileImageUrl   https://pbs.twimg.com/profile_images/117513767...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/78858425...
# url                                 https://twitter.com/LizWilcox79
#
#                                                                   2  \
# username                                                  PodRevDay
# displayname                                               PodRevDay
# id                                              1258481717431750656
# description       Podcast Review Day,monthly Podcast Listener pa...
# rawDescription    Podcast Review Day,monthly Podcast Listener pa...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                  720
# friendsCount                                                    624
# statusesCount                                                  1427
# favouritesCount                                                1130
# listedCount                                                       4
# mediaCount                                                      210
# location                                                      World
# protected                                                     False
# linkUrl                                        http://podrevday.com
# linkTcourl                                  https://t.co/l4qxDl2PqG
# profileImageUrl   https://pbs.twimg.com/profile_images/126529355...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay
#
#                                                                   3  \
# username                                               KidsWatching
# displayname                     Kids, What Are We Watching Tonight?
# id                                              1329802414787088388
# description       A lockdown project that grew arms and legs.  A...
# rawDescription    A lockdown project that grew arms and legs.  A...
# descriptionUrls   [{'text': 'buzzsprout.com/1207745', 'url': 'ht...
# verified                                                      False
# created                                   2020-11-20T15:04:58+00:00
# followersCount                                                   64
# friendsCount                                                     55
# statusesCount                                                   331
# favouritesCount                                                 445
# listedCount                                                       0
# mediaCount                                                      141
# location
# protected                                                     False
# linkUrl                          https://www.buzzsprout.com/1207745
# linkTcourl                                  https://t.co/c4BNCzUmGu
# profileImageUrl   https://pbs.twimg.com/profile_images/132980325...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/13298024...
# url                                https://twitter.com/KidsWatching
#
#                                                                   4
# username                                                  PodRevDay
# displayname                                               PodRevDay
# id                                              1258481717431750656
# description       Podcast Review Day,monthly Podcast Listener pa...
# rawDescription    Podcast Review Day,monthly Podcast Listener pa...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                  720
# friendsCount                                                    624
# statusesCount                                                  1427
# favouritesCount                                                1130
# listedCount                                                       4
# mediaCount                                                      210
# location                                                      World
# protected                                                     False
# linkUrl                                        http://podrevday.com
# linkTcourl                                  https://t.co/l4qxDl2PqG
# profileImageUrl   https://pbs.twimg.com/profile_images/126529355...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay

# %%
len(set(pod_rev_users.username))
# Out:
# 401

# %%
pod_rev_users = pod_rev_users.drop_duplicates(subset=['username'])

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                             LaydenRobinson
# displayname                                         Layden Robinson
# id                                                         42290868
# description       "Don't ever be ashamed of your story.  Somewhe...
# rawDescription    "Don't ever be ashamed of your story.  Somewhe...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2009-05-24T22:04:27+00:00
# followersCount                                                82326
# friendsCount                                                  90220
# statusesCount                                                689046
# favouritesCount                                              123045
# listedCount                                                    1711
# mediaCount                                                   283832
# location                                              San Diego, CA
# protected                                                     False
# linkUrl           https://laydenrobinson.bandcamp.com/album/arti...
# linkTcourl                                  https://t.co/LEo8TazGhI
# profileImageUrl   https://pbs.twimg.com/profile_images/917740321...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/42290868...
# url                              https://twitter.com/LaydenRobinson
#
#                                                                   1  \
# username                                                LizWilcox79
# displayname                                        Elizabeth Wilcox
# id                                               788584258826665984
# description       Writer, Avid Role-Player, Amateur Mixologist, ...
# rawDescription    Writer, Avid Role-Player, Amateur Mixologist, ...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2016-10-19T03:35:13+00:00
# followersCount                                                  314
# friendsCount                                                    457
# statusesCount                                                  1686
# favouritesCount                                               11108
# listedCount                                                       0
# mediaCount                                                      228
# location                                                  Tempe, AZ
# protected                                                     False
# linkUrl                              https://www.briarbooklane.com/
# linkTcourl                                  https://t.co/FmtWS2qcaY
# profileImageUrl   https://pbs.twimg.com/profile_images/117513767...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/78858425...
# url                                 https://twitter.com/LizWilcox79
#
#                                                                   2  \
# username                                                  PodRevDay
# displayname                                               PodRevDay
# id                                              1258481717431750656
# description       Podcast Review Day,monthly Podcast Listener pa...
# rawDescription    Podcast Review Day,monthly Podcast Listener pa...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-05-07T19:40:12+00:00
# followersCount                                                  720
# friendsCount                                                    624
# statusesCount                                                  1427
# favouritesCount                                                1130
# listedCount                                                       4
# mediaCount                                                      210
# location                                                      World
# protected                                                     False
# linkUrl                                        http://podrevday.com
# linkTcourl                                  https://t.co/l4qxDl2PqG
# profileImageUrl   https://pbs.twimg.com/profile_images/126529355...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12584817...
# url                                   https://twitter.com/PodRevDay
#
#                                                                   3  \
# username                                               KidsWatching
# displayname                     Kids, What Are We Watching Tonight?
# id                                              1329802414787088388
# description       A lockdown project that grew arms and legs.  A...
# rawDescription    A lockdown project that grew arms and legs.  A...
# descriptionUrls   [{'text': 'buzzsprout.com/1207745', 'url': 'ht...
# verified                                                      False
# created                                   2020-11-20T15:04:58+00:00
# followersCount                                                   64
# friendsCount                                                     55
# statusesCount                                                   331
# favouritesCount                                                 445
# listedCount                                                       0
# mediaCount                                                      141
# location
# protected                                                     False
# linkUrl                          https://www.buzzsprout.com/1207745
# linkTcourl                                  https://t.co/c4BNCzUmGu
# profileImageUrl   https://pbs.twimg.com/profile_images/132980325...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/13298024...
# url                                https://twitter.com/KidsWatching
#
#                                                                   5
# username                                                stephfuccio
# displayname                                        Stephanie Fuccio
# id                                                        153349145
# description       Freelance Podcast Editor | Host/Producer:Geopa...
# rawDescription    Freelance Podcast Editor | Host/Producer:Geopa...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2010-06-08T09:24:09+00:00
# followersCount                                                 2233
# friendsCount                                                   2376
# statusesCount                                                 17188
# favouritesCount                                                6689
# listedCount                                                     109
# mediaCount                                                     2306
# location                                                    Albania
# protected                                                     False
# linkUrl                    https://www.stephfuccio.com/editing.html
# linkTcourl                                  https://t.co/z1JdpLGtcf
# profileImageUrl   https://pbs.twimg.com/profile_images/132762979...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/15334914...
# url                                 https://twitter.com/stephfuccio

# %%
pod_rev_users.shape
# Out:
# (401, 21)

# %% [markdown]
# # Clean User Data

# %%
df_users = pod_rev_users.loc[:, ['id','username', 'displayname', 'location', 'created', 'followersCount', 'friendsCount', 'url', 'verified' ]]

# %%
def location_extraction (df):
    '''Creates creates a geotext column to extract city and country info if possible'''

    df.loc[:, "location"] = df.loc[:, "location"].fillna("blank")
    df.loc[:, "geotext"] = df.loc[:, "location"].apply(GeoText)
    df.loc[:, 'city'] = df.loc[:, 'geotext'].apply(lambda x: x.cities)
    df.loc[:, 'country'] = df.loc[:, 'geotext'].apply(lambda x: x.countries)
    
    return df

df_users = location_extraction(df_users)

# %%
from geonamescache import GeonamesCache
gc = GeonamesCache()
countries = gc.get_countries()
country_info = pd.DataFrame(countries).T
country_info = country_info.set_index('geonameid').reset_index()
name_code = country_info.loc[:, ["name", "iso3"]]

us_states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
             "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA",
             "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY",
             "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX",
             "UT", "VT", "VA", "WA", "WV", "WI", "WY", "USA", "United States",
             'Seattle', "Los Angeles", "Houston", "Atlanta", "Pittsburgh"]

us_state_names = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", 
               "District ", "of Columbia", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", 
               "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", 
               "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", 
               "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", 
               "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", 
               "Wisconsin", "West Virginia", "Wyoming"]

can_prov_abbrev = {'Alberta': 'AB','British Columbia': 'BC','Manitoba': 'MB', 'New Brunswick': 'NB',
                       'Newfoundland and Labrador': 'NL', 'Northwest Territories': 'NT','Nova Scotia': 'NS','Nunavut': 'NU',
                       'Ontario': 'ON','Prince Edward Island': 'PE', 'Quebec': 'QC','Saskatchewan': 'SK','Yukon': 'YT'}

can_prov_names, can_prov_abbr = zip(*can_prov_abbrev.items())

uk = ["England", 'Wales', "Scotland", 'London', "Manchester", "Isle of Wight", "Northern Ireland", "United Kingdom", 'Bailiwick of Guernsey', "UK", "Hoxton", "Jersey"]

india_city = ["Bangalore", "Delhi", "Hyderabad", "Bengaluru"]

german_city = ["Munich", "Berlin", "eisgau","Hamburg", "Dortmund"]

south_africa = ["South Africa", "Durban", "Johannesburg"]

uae = ['UAE', 'Dubai', 'Abu Dhabi']

def replacer(area, name):
    df_users.loc[(df_users.location.str.contains('|'.join(area))), "country"] = name    
    return df_users

def list_to_string(df):
    df["city"] = df['city'].apply(lambda x: "".join(map(str, x)))
    df["country"] = df['country'].apply(lambda x: "".join(map(str, x)))
    
    return df

# %%
def location_cleaner(df):
    df = replacer(can_prov_names, "Canada")
    df = replacer(can_prov_abbrev, "Canada")
    df = replacer(us_state_names, "United States")
    df = replacer(us_states, "United States")
    df = replacer(uk, "United Kingdom")
    df = replacer(german_city, "Germany")
    df = replacer(south_africa, "South Africa")
    df = replacer(india_city, "India")
    df = replacer(uae, 'United Arab Emirates')
    df.loc[(df.location == "Italia"), "country"] = "Italy" 
    df.loc[(df.location == "Belgrade"), "country"] = "Serbia" 
    df.loc[(df.country == "PolandSerbia"), "country"] = "Poland" 
    df = list_to_string(df)
    
    return df

# %%
df_users = location_cleaner(df_users)
df_users.loc[(df_users.country == "PolandSerbia"), "country"] = "Poland"

# %%
df_users.country.value_counts()
# Out:
#                         176
# United States           145
# United Kingdom           36
# Canada                   17
# Germany                   6
# Poland                    3
# Australia                 3
# India                     2
# Spain                     2
# Malaysia                  1
# Sweden                    1
# New Zealand               1
# Albania                   1
# United Arab Emirates      1
# France                    1
# Vietnam                   1
# Italy                     1
# Nigeria                   1
# Serbia                    1
# Ecuador                   1
# Name: country, dtype: int64

# %%
df_users_full = pd.merge(left=df_users,
                    right=name_code,
                    how='left',
                    left_on='country',
                    right_on='name')

# %%
df_users_full.head()
# Out:
#                     id        username                          displayname  \
# 0             42290868  LaydenRobinson                      Layden Robinson
# 1   788584258826665984     LizWilcox79                     Elizabeth Wilcox
# 2  1258481717431750656       PodRevDay                            PodRevDay
# 3  1329802414787088388    KidsWatching  Kids, What Are We Watching Tonight?
# 4            153349145     stephfuccio                     Stephanie Fuccio
#
#         location                    created  followersCount  friendsCount  \
# 0  San Diego, CA  2009-05-24T22:04:27+00:00           82326         90220
# 1      Tempe, AZ  2016-10-19T03:35:13+00:00             314           457
# 2          World  2020-05-07T19:40:12+00:00             720           624
# 3                 2020-11-20T15:04:58+00:00              64            55
# 4        Albania  2010-06-08T09:24:09+00:00            2233          2376
#
#                                   url  verified  \
# 0  https://twitter.com/LaydenRobinson     False
# 1     https://twitter.com/LizWilcox79     False
# 2       https://twitter.com/PodRevDay     False
# 3    https://twitter.com/KidsWatching     False
# 4     https://twitter.com/stephfuccio     False
#
#                                              geotext       city  \
# 0  <geotext.geotext.GeoText object at 0x7fc5a2927...  San Diego
# 1  <geotext.geotext.GeoText object at 0x7fc5a2927...      Tempe
# 2  <geotext.geotext.GeoText object at 0x7fc5a2927...
# 3  <geotext.geotext.GeoText object at 0x7fc5a2927...
# 4  <geotext.geotext.GeoText object at 0x7fc5a2927...
#
#          country           name iso3
# 0  United States  United States  USA
# 1  United States  United States  USA
# 2                           NaN  NaN
# 3                           NaN  NaN
# 4        Albania        Albania  ALB

# %% [markdown]
# ## Update Followers Data

# %%
df_users.to_csv('data/user_data.csv')

# %% [markdown]
# # Merge User's Geographic Data with Tweets

# %%
full_df = pd.merge(left=df_tweets_new, 
                   right=df_users_full, 
                   how='left',
                   on='username')

full_df.to_csv('data/tweets_users_feb_21.csv', index=False)
