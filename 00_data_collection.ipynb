# %% [markdown]
# # Get All Tweets with #PodRevDay

# %%
# Get the data
# !snscrape --jsonl twitter-hashtag "#podrevday since:2020-01-01 until:2021-05-10" > 'data/jan20_may21.json'

# %%
import pandas as pd
from geotext import GeoText

df_tweets_old = pd.read_json('data/jan20_apr21.json', lines=True)
df_tweets_new = pd.read_json('data/jan20_may21.json', lines=True)

# %%
print(df_tweets_old.shape)
print(df_tweets_new.shape)
print(f'Number of tweets last month useing #podrevday: {df_tweets_new.shape[0] - df_tweets_old.shape[0]}')
# Out:
# (2097, 21)
# (2187, 21)
# Number of tweets last month useing #podrevday: 90

# %%
df_tweets_new.head().T
# Out:
#                                                                  0  \
# url              https://twitter.com/CaseyBroda/status/13912635...
# date                                     2021-05-09 05:27:44+00:00
# content          Finishing #PodRevDay with wine 🍷 and listening...
# renderedContent  Finishing #PodRevDay with wine 🍷 and listening...
# id                                             1391263596877737984
# user             {'username': 'CaseyBroda', 'displayname': 'Cas...
# outlinks                                                        []
# tcooutlinks                                                     []
# replyCount                                                       2
# retweetCount                                                     1
# likeCount                                                        2
# quoteCount                                                       0
# conversationId                                 1391263596877737984
# lang                                                            en
# source           <a href="http://twitter.com/download/iphone" r...
# sourceUrl                       http://twitter.com/download/iphone
# sourceLabel                                     Twitter for iPhone
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'ConnorLites', 'displayname': 'C...
#
#                                                                  1  \
# url              https://twitter.com/OracleofDusk/status/139125...
# date                                     2021-05-09 04:42:51+00:00
# content          Started with @9thWorldJournal and then a new e...
# renderedContent  Started with @9thWorldJournal and then a new e...
# id                                             1391252303294906370
# user             {'username': 'OracleofDusk', 'displayname': 'M...
# outlinks         [https://www.podchaser.com/podcasts/a-ninth-wo...
# tcooutlinks                              [https://t.co/4S5ZKd5RPD]
# replyCount                                                       0
# retweetCount                                                     1
# likeCount                                                        1
# quoteCount                                                       0
# conversationId                                 1391252303294906370
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': '9thWorldJournal', 'displayname'...
#
#                                                                  2  \
# url              https://twitter.com/OracleofDusk/status/139123...
# date                                     2021-05-09 03:25:02+00:00
# content          22nd #PodRevDay Review is for an episode of @W...
# renderedContent  22nd #PodRevDay Review is for an episode of @W...
# id                                             1391232716180439043
# user             {'username': 'OracleofDusk', 'displayname': 'M...
# outlinks         [https://www.podchaser.com/podcasts/westside-f...
# tcooutlinks                              [https://t.co/MKyo0JN1UU]
# replyCount                                                       0
# retweetCount                                                     1
# likeCount                                                        2
# quoteCount                                                       1
# conversationId                                 1391232716180439043
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'WSFairytales', 'displayname': '...
#
#                                                                  3  \
# url              https://twitter.com/OracleofDusk/status/139123...
# date                                     2021-05-09 03:16:25+00:00
# content          21st review for this #PodRevDay (*wipes sweat ...
# renderedContent  21st review for this #PodRevDay (*wipes sweat ...
# id                                             1391230549335883778
# user             {'username': 'OracleofDusk', 'displayname': 'M...
# outlinks         [https://www.podchaser.com/podcasts/whatsherna...
# tcooutlinks                              [https://t.co/UIIinRqCoj]
# replyCount                                                       1
# retweetCount                                                     2
# likeCount                                                        2
# quoteCount                                                       0
# conversationId                                 1391230549335883778
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'WhatsHerNamePC', 'displayname':...
#
#                                                                  4
# url              https://twitter.com/OracleofDusk/status/139122...
# date                                     2021-05-09 03:12:09+00:00
# content          .@MissionRejected is back!!!! In time for my 2...
# renderedContent  .@MissionRejected is back!!!! In time for my 2...
# id                                             1391229474591674384
# user             {'username': 'OracleofDusk', 'displayname': 'M...
# outlinks         [https://www.podchaser.com/podcasts/mission-re...
# tcooutlinks                              [https://t.co/4MdXSFLdJp]
# replyCount                                                       0
# retweetCount                                                     2
# likeCount                                                        5
# quoteCount                                                       0
# conversationId                                 1391229474591674384
# lang                                                            en
# source           <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                               https://mobile.twitter.com
# sourceLabel                                        Twitter Web App
# media                                                         None
# retweetedTweet                                                 NaN
# quotedTweet                                                   None
# mentionedUsers   [{'username': 'MissionRejected', 'displayname'...

# %% [markdown]
# # Get User Data

# %%
# for i in range(len(df_tweets_new['user'])):
#     print(df_tweets_new['user'][i]["username"])

# %%
df_tweets_new.user[0]
# Out:
# {'username': 'CaseyBroda',
#  'displayname': 'Casey Broda',
#  'id': 533456292,
#  'description': 'Podcast Editor & Manager. Social Media Graphics. Photographer. Hiker.',
#  'rawDescription': 'Podcast Editor & Manager. Social Media Graphics. Photographer. Hiker.',
#  'descriptionUrls': [],
#  'verified': False,
#  'created': '2012-03-22T18:35:49+00:00',
#  'followersCount': 176,
#  'friendsCount': 333,
#  'statusesCount': 724,
#  'favouritesCount': 5360,
#  'listedCount': 1,
#  'mediaCount': 216,
#  'location': 'Currently Seattle, WA',
#  'protected': False,
#  'linkUrl': 'https://linktr.ee/CaseyBroda',
#  'linkTcourl': 'https://t.co/EvV8vhWnVQ',
#  'profileImageUrl': 'https://pbs.twimg.com/profile_images/1360485764295921666/fr411izd_normal.jpg',
#  'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/533456292/1620019673',
#  'url': 'https://twitter.com/CaseyBroda'}

# %%
df_tweets_new['username'] = df_tweets_new['url'].str.split('/').str[3]

# %%
#pd.DataFrame(ser.tolist())
pod_rev_users = pd.DataFrame(df_tweets_new.user.to_list())

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                                 CaseyBroda
# displayname                                             Casey Broda
# id                                                        533456292
# description       Podcast Editor & Manager. Social Media Graphic...
# rawDescription    Podcast Editor & Manager. Social Media Graphic...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2012-03-22T18:35:49+00:00
# followersCount                                                  176
# friendsCount                                                    333
# statusesCount                                                   724
# favouritesCount                                                5360
# listedCount                                                       1
# mediaCount                                                      216
# location                                      Currently Seattle, WA
# protected                                                     False
# linkUrl                                https://linktr.ee/CaseyBroda
# linkTcourl                                  https://t.co/EvV8vhWnVQ
# profileImageUrl   https://pbs.twimg.com/profile_images/136048576...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/53345629...
# url                                  https://twitter.com/CaseyBroda
#
#                                                                   1  \
# username                                               OracleofDusk
# displayname                                               MJ Bailey
# id                                              1087100443761758208
# description       the story of a reluctant oracle. and maybe... ...
# rawDescription    the story of a reluctant oracle. and maybe... ...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2019-01-20T21:31:57+00:00
# followersCount                                                  819
# friendsCount                                                   1841
# statusesCount                                                  2439
# favouritesCount                                                3882
# listedCount                                                       8
# mediaCount                                                      290
# location
# protected                                                     False
# linkUrl                                  http://oracleofdusk.online
# linkTcourl                                  https://t.co/sTfHhVd0AQ
# profileImageUrl   https://pbs.twimg.com/profile_images/134159538...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/10871004...
# url                                https://twitter.com/OracleofDusk
#
#                                                                   2  \
# username                                               OracleofDusk
# displayname                                               MJ Bailey
# id                                              1087100443761758208
# description       the story of a reluctant oracle. and maybe... ...
# rawDescription    the story of a reluctant oracle. and maybe... ...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2019-01-20T21:31:57+00:00
# followersCount                                                  819
# friendsCount                                                   1841
# statusesCount                                                  2439
# favouritesCount                                                3882
# listedCount                                                       8
# mediaCount                                                      290
# location
# protected                                                     False
# linkUrl                                  http://oracleofdusk.online
# linkTcourl                                  https://t.co/sTfHhVd0AQ
# profileImageUrl   https://pbs.twimg.com/profile_images/134159538...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/10871004...
# url                                https://twitter.com/OracleofDusk
#
#                                                                   3  \
# username                                               OracleofDusk
# displayname                                               MJ Bailey
# id                                              1087100443761758208
# description       the story of a reluctant oracle. and maybe... ...
# rawDescription    the story of a reluctant oracle. and maybe... ...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2019-01-20T21:31:57+00:00
# followersCount                                                  819
# friendsCount                                                   1841
# statusesCount                                                  2439
# favouritesCount                                                3882
# listedCount                                                       8
# mediaCount                                                      290
# location
# protected                                                     False
# linkUrl                                  http://oracleofdusk.online
# linkTcourl                                  https://t.co/sTfHhVd0AQ
# profileImageUrl   https://pbs.twimg.com/profile_images/134159538...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/10871004...
# url                                https://twitter.com/OracleofDusk
#
#                                                                   4
# username                                               OracleofDusk
# displayname                                               MJ Bailey
# id                                              1087100443761758208
# description       the story of a reluctant oracle. and maybe... ...
# rawDescription    the story of a reluctant oracle. and maybe... ...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2019-01-20T21:31:57+00:00
# followersCount                                                  819
# friendsCount                                                   1841
# statusesCount                                                  2439
# favouritesCount                                                3882
# listedCount                                                       8
# mediaCount                                                      290
# location
# protected                                                     False
# linkUrl                                  http://oracleofdusk.online
# linkTcourl                                  https://t.co/sTfHhVd0AQ
# profileImageUrl   https://pbs.twimg.com/profile_images/134159538...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/10871004...
# url                                https://twitter.com/OracleofDusk

# %%
len(set(pod_rev_users.username))
# Out:
# 458

# %%
pod_rev_users = pod_rev_users.drop_duplicates(subset=['username'])

# %%
pod_rev_users.head().T
# Out:
#                                                                  0   \
# username                                                 CaseyBroda
# displayname                                             Casey Broda
# id                                                        533456292
# description       Podcast Editor & Manager. Social Media Graphic...
# rawDescription    Podcast Editor & Manager. Social Media Graphic...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2012-03-22T18:35:49+00:00
# followersCount                                                  176
# friendsCount                                                    333
# statusesCount                                                   724
# favouritesCount                                                5360
# listedCount                                                       1
# mediaCount                                                      216
# location                                      Currently Seattle, WA
# protected                                                     False
# linkUrl                                https://linktr.ee/CaseyBroda
# linkTcourl                                  https://t.co/EvV8vhWnVQ
# profileImageUrl   https://pbs.twimg.com/profile_images/136048576...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/53345629...
# url                                  https://twitter.com/CaseyBroda
#
#                                                                  1   \
# username                                               OracleofDusk
# displayname                                               MJ Bailey
# id                                              1087100443761758208
# description       the story of a reluctant oracle. and maybe... ...
# rawDescription    the story of a reluctant oracle. and maybe... ...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2019-01-20T21:31:57+00:00
# followersCount                                                  819
# friendsCount                                                   1841
# statusesCount                                                  2439
# favouritesCount                                                3882
# listedCount                                                       8
# mediaCount                                                      290
# location
# protected                                                     False
# linkUrl                                  http://oracleofdusk.online
# linkTcourl                                  https://t.co/sTfHhVd0AQ
# profileImageUrl   https://pbs.twimg.com/profile_images/134159538...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/10871004...
# url                                https://twitter.com/OracleofDusk
#
#                                                                  15  \
# username                                               StorytellPod
# displayname                        Story of a Storyteller - Podcast
# id                                              1104380581817782273
# description       Interview podcast where Storytellers share the...
# rawDescription    Interview podcast where Storytellers share the...
# descriptionUrls   [{'text': 'bit.ly/2D9dx5O', 'url': 'http://bit...
# verified                                                      False
# created                                   2019-03-09T13:57:03+00:00
# followersCount                                                  777
# friendsCount                                                    690
# statusesCount                                                  1348
# favouritesCount                                                1956
# listedCount                                                       6
# mediaCount                                                      119
# location                                       Dublin City, Ireland
# protected                                                     False
# linkUrl                          http://www.conorbredin.com/podcast
# linkTcourl                                  https://t.co/tbKCTZx9Z5
# profileImageUrl   https://pbs.twimg.com/profile_images/130256946...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/11043805...
# url                                https://twitter.com/StorytellPod
#
#                                                                  16  \
# username                                                  Podchaser
# displayname                                               Podchaser
# id                                               772231864937361408
# description       Powering podcast discovery for listeners, podc...
# rawDescription    Powering podcast discovery for listeners, podc...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2016-09-04T00:36:38+00:00
# followersCount                                                23140
# friendsCount                                                   9486
# statusesCount                                                 10813
# favouritesCount                                               28218
# listedCount                                                     270
# mediaCount                                                     1549
# location
# protected                                                     False
# linkUrl                                    http://www.podchaser.com
# linkTcourl                                  https://t.co/hH01JVrAop
# profileImageUrl   https://pbs.twimg.com/profile_images/126820969...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/77223186...
# url                                   https://twitter.com/Podchaser
#
#                                                                  18
# username                                               NightPostPod
# displayname                                    The Night Post 💌🏳️‍🌈
# id                                              1344402723991662598
# description       Gilt City's conscripted couriers face the anci...
# rawDescription    Gilt City's conscripted couriers face the anci...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2020-12-30T21:59:28+00:00
# followersCount                                                  206
# friendsCount                                                    162
# statusesCount                                                   255
# favouritesCount                                                 433
# listedCount                                                       4
# mediaCount                                                       31
# location
# protected                                                     False
# linkUrl                                   https://nightpostpod.com/
# linkTcourl                                  https://t.co/ccnHrXIPuK
# profileImageUrl   https://pbs.twimg.com/profile_images/134831217...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/13444027...
# url                                https://twitter.com/NightPostPod

# %%
pod_rev_users.shape
# Out:
# (458, 21)

# %% [markdown]
# # Clean User Data

# %%
df_users = pod_rev_users.loc[:, ['id','username', 'displayname', 'location', 'created', 'followersCount', 'friendsCount', 'url', 'verified' ]]

# %%
def location_extraction (df):
    '''Creates creates a geotext column to extract city and country info if possible'''

    df.loc[:, "location"] = df.loc[:, "location"].fillna("blank")
    df.loc[:, "geotext"] = df.loc[:, "location"].apply(GeoText)
    df.loc[:, 'city'] = df.loc[:, 'geotext'].apply(lambda x: x.cities)
    df.loc[:, 'country'] = df.loc[:, 'geotext'].apply(lambda x: x.countries)
    
    return df

df_users = location_extraction(df_users)

# %%
from geonamescache import GeonamesCache
gc = GeonamesCache()
countries = gc.get_countries()
country_info = pd.DataFrame(countries).T
country_info = country_info.set_index('geonameid').reset_index()
name_code = country_info.loc[:, ["name", "iso3"]]

us_states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
             "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA",
             "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY",
             "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX",
             "UT", "VT", "VA", "WA", "WV", "WI", "WY", "USA", "United States",
             'Seattle', "Los Angeles", "Houston", "Atlanta", "Pittsburgh"]

us_state_names = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", 
               "District ", "of Columbia", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", 
               "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", 
               "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", 
               "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", 
               "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", 
               "Wisconsin", "West Virginia", "Wyoming"]

can_prov_abbrev = {'Alberta': 'AB','British Columbia': 'BC','Manitoba': 'MB', 'New Brunswick': 'NB',
                       'Newfoundland and Labrador': 'NL', 'Northwest Territories': 'NT','Nova Scotia': 'NS','Nunavut': 'NU',
                       'Ontario': 'ON','Prince Edward Island': 'PE', 'Quebec': 'QC','Saskatchewan': 'SK','Yukon': 'YT'}

can_prov_names, can_prov_abbr = zip(*can_prov_abbrev.items())

uk = ["England", 'Wales', "Scotland", 'London', "Manchester", "Isle of Wight", "Northern Ireland", "United Kingdom", 'Bailiwick of Guernsey', "UK", "Hoxton", "Jersey"]

india_city = ["Bangalore", "Delhi", "Hyderabad", "Bengaluru"]

german_city = ["Munich", "Berlin", "eisgau","Hamburg", "Dortmund"]

south_africa = ["South Africa", "Durban", "Johannesburg"]

south_korea = ["Republic of Korea"]

uae = ['UAE', 'Dubai', 'Abu Dhabi']


def replacer(area, name):
    df_users.loc[(df_users.location.str.contains('|'.join(area))), "country"] = name    
    return df_users

def list_to_string(df):
    df["city"] = df['city'].apply(lambda x: "".join(map(str, x)))
    df["country"] = df['country'].apply(lambda x: "".join(map(str, x)))
    
    return df

# %%
def location_cleaner(df):
    df = replacer(can_prov_names, "Canada")
    df = replacer(can_prov_abbrev, "Canada")
    df = replacer(us_state_names, "United States")
    df = replacer(us_states, "United States")
    df = replacer(uk, "United Kingdom")
    df = replacer(german_city, "Germany")
    df = replacer(south_africa, "South Africa")
    df = replacer(india_city, "India")
    df = replacer(uae, 'United Arab Emirates')
    df = replacer(south_korea, "South Korea")
    df.loc[(df.location == "Italia"), "country"] = "Italy" 
    df.loc[(df.location == "Belgrade"), "country"] = "Serbia" 
    df.loc[(df.country == "PolandSerbia"), "country"] = "Poland" 
    df = list_to_string(df)
    
    return df

# %%
df_users = location_cleaner(df_users)
df_users.loc[(df_users.country == "PolandSerbia"), "country"] = "Poland"

# %%
df_users.country.value_counts()
# Out:
#                         200
# United States           161
# United Kingdom           44
# Canada                   21
# Germany                   6
# Poland                    3
# India                     3
# Australia                 3
# Ireland                   2
# Malaysia                  2
# Spain                     2
# Vietnam                   1
# Vanuatu                   1
# Albania                   1
# Italy                     1
# Ecuador                   1
# United Arab Emirates      1
# New Zealand               1
# France                    1
# Sweden                    1
# Nigeria                   1
# South Korea               1
# Name: country, dtype: int64

# %%
df_users_full = pd.merge(left=df_users,
                    right=name_code,
                    how='left',
                    left_on='country',
                    right_on='name')

# %%
df_users_full.head()
# Out:
#                     id      username                       displayname  \
# 0            533456292    CaseyBroda                       Casey Broda
# 1  1087100443761758208  OracleofDusk                         MJ Bailey
# 2  1104380581817782273  StorytellPod  Story of a Storyteller - Podcast
# 3   772231864937361408     Podchaser                         Podchaser
# 4  1344402723991662598  NightPostPod              The Night Post 💌🏳️‍🌈
#
#                 location                    created  followersCount  \
# 0  Currently Seattle, WA  2012-03-22T18:35:49+00:00             176
# 1                         2019-01-20T21:31:57+00:00             819
# 2   Dublin City, Ireland  2019-03-09T13:57:03+00:00             777
# 3                         2016-09-04T00:36:38+00:00           23140
# 4                         2020-12-30T21:59:28+00:00             206
#
#    friendsCount                               url  verified  \
# 0           333    https://twitter.com/CaseyBroda     False
# 1          1841  https://twitter.com/OracleofDusk     False
# 2           690  https://twitter.com/StorytellPod     False
# 3          9486     https://twitter.com/Podchaser     False
# 4           162  https://twitter.com/NightPostPod     False
#
#                                              geotext city        country  \
# 0  <geotext.geotext.GeoText object at 0x7fa63063d...       United States
# 1  <geotext.geotext.GeoText object at 0x7fa630639...
# 2  <geotext.geotext.GeoText object at 0x7fa630639...             Ireland
# 3  <geotext.geotext.GeoText object at 0x7fa60714a...
# 4  <geotext.geotext.GeoText object at 0x7fa60714a...
#
#             name iso3
# 0  United States  USA
# 1            NaN  NaN
# 2        Ireland  IRL
# 3            NaN  NaN
# 4            NaN  NaN

# %% [markdown]
# ## Update Followers Data

# %%
df_users.to_csv('data/user_data.csv')

# %% [markdown]
# # Merge User's Geographic Data with Tweets

# %%
full_df = pd.merge(left=df_tweets_new, 
                   right=df_users_full, 
                   how='left',
                   on='username')

full_df.to_csv('data/tweets_users_may_21.csv', index=False)

# %%
full_df.shape
# Out:
# (2187, 35)
