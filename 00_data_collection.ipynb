# %% [markdown]
# # Get All Tweets with #PodRevDay

# %%
# Get the data
# !snscrape --jsonl twitter-hashtag "#podrevday since:2020-01-01 until:2021-10-10" > 'data/jan20_oct21.json'

# %%
import pandas as pd
from geotext import GeoText

df_tweets = pd.read_json('data/jan20_oct21.json', lines=True)

# %%
df_tweets.shape
# Out:
# (3163, 21)

# %%
df_tweets.to_csv('data/jan20_oct21.json', index=False)

# %% [markdown]
# # Get User Data

# %%
df_tweets.user[0]
# Out:
# {'username': 'thatangellove',
#  'displayname': 'Angel Lovecchio',
#  'id': 2577871830,
#  'description': 'Clarifying complexities so that we realize our power to create the world around us.',
#  'rawDescription': 'Clarifying complexities so that we realize our power to create the world around us.',
#  'descriptionUrls': [],
#  'verified': False,
#  'created': '2014-06-20T02:43:31+00:00',
#  'followersCount': 56,
#  'friendsCount': 259,
#  'statusesCount': 138,
#  'favouritesCount': 384,
#  'listedCount': 0,
#  'mediaCount': 22,
#  'location': 'TN ',
#  'protected': False,
#  'linkUrl': None,
#  'linkTcourl': None,
#  'profileImageUrl': 'https://pbs.twimg.com/profile_images/1380323964300443650/YnkqquJF_normal.jpg',
#  'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/2577871830/1611515065',
#  'url': 'https://twitter.com/thatangellove'}

# %%
df_tweets['username'] = df_tweets['url'].str.split('/').str[3]

# %%
pod_rev_users = pd.DataFrame(df_tweets.user.to_list())

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                              thatangellove
# displayname                                         Angel Lovecchio
# id                                                       2577871830
# description       Clarifying complexities so that we realize our...
# rawDescription    Clarifying complexities so that we realize our...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2014-06-20T02:43:31+00:00
# followersCount                                                   56
# friendsCount                                                    259
# statusesCount                                                   138
# favouritesCount                                                 384
# listedCount                                                       0
# mediaCount                                                       22
# location                                                        TN
# protected                                                     False
# linkUrl                                                        None
# linkTcourl                                                     None
# profileImageUrl   https://pbs.twimg.com/profile_images/138032396...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/25778718...
# url                               https://twitter.com/thatangellove
#
#                                                                   1  \
# username                                              thatangellove
# displayname                                         Angel Lovecchio
# id                                                       2577871830
# description       Clarifying complexities so that we realize our...
# rawDescription    Clarifying complexities so that we realize our...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2014-06-20T02:43:31+00:00
# followersCount                                                   56
# friendsCount                                                    259
# statusesCount                                                   138
# favouritesCount                                                 384
# listedCount                                                       0
# mediaCount                                                       22
# location                                                        TN
# protected                                                     False
# linkUrl                                                        None
# linkTcourl                                                     None
# profileImageUrl   https://pbs.twimg.com/profile_images/138032396...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/25778718...
# url                               https://twitter.com/thatangellove
#
#                                                                   2  \
# username                                               chainofbeing
# displayname         Chain of Being | Mythic Science Fiction Podcast
# id                                               836274023180951552
# description       A glimpse into the future: where gods control ...
# rawDescription    A glimpse into the future: where gods control ...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2017-02-27T17:57:19+00:00
# followersCount                                                  669
# friendsCount                                                   1086
# statusesCount                                                  2114
# favouritesCount                                                6229
# listedCount                                                       8
# mediaCount                                                       99
# location
# protected                                                     False
# linkUrl                    https://www.patreon.com/faustiannonsense
# linkTcourl                                  https://t.co/hI7TP3NOSh
# profileImageUrl   https://pbs.twimg.com/profile_images/131637658...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/83627402...
# url                                https://twitter.com/chainofbeing
#
#                                                                   3  \
# username                                            greenhorizonpod
# displayname         The Green Horizon | Irish Indie Audio Drama 🇮🇪🚀
# id                                              1212088323885301760
# description       That show about Irish people in space. Proud m...
# rawDescription    That show about Irish people in space. Proud m...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2019-12-31T19:09:21+00:00
# followersCount                                                  881
# friendsCount                                                    670
# statusesCount                                                  1591
# favouritesCount                                                2923
# listedCount                                                       8
# mediaCount                                                      272
# location                                     Waterford, Ireland 🇮🇪
# protected                                                     False
# linkUrl           https://www.faustiannonsense.com/the-green-hor...
# linkTcourl                                  https://t.co/3DrySkK3en
# profileImageUrl   https://pbs.twimg.com/profile_images/136388024...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12120883...
# url                             https://twitter.com/greenhorizonpod
#
#                                                                   4
# username                                                 CaseyBroda
# displayname                                             Casey Broda
# id                                                        533456292
# description          Podcast Editor & Manager. Photographer. Hiker.
# rawDescription       Podcast Editor & Manager. Photographer. Hiker.
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2012-03-22T18:35:49+00:00
# followersCount                                                  415
# friendsCount                                                    431
# statusesCount                                                  2216
# favouritesCount                                               14573
# listedCount                                                       6
# mediaCount                                                      626
# location                                      Currently Seattle, WA
# protected                                                     False
# linkUrl                                      https://caseybroda.com
# linkTcourl                                  https://t.co/5brq3XKxE1
# profileImageUrl   https://pbs.twimg.com/profile_images/136048576...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/53345629...
# url                                  https://twitter.com/CaseyBroda

# %%
len(set(pod_rev_users.username))
# Out:
# 617

# %%
pod_rev_users = pod_rev_users.drop_duplicates(subset=['username'])
len(pod_rev_users)
# Out:
# 617

# %%
pod_rev_users.head().T
# Out:
#                                                                   0  \
# username                                              thatangellove
# displayname                                         Angel Lovecchio
# id                                                       2577871830
# description       Clarifying complexities so that we realize our...
# rawDescription    Clarifying complexities so that we realize our...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2014-06-20T02:43:31+00:00
# followersCount                                                   56
# friendsCount                                                    259
# statusesCount                                                   138
# favouritesCount                                                 384
# listedCount                                                       0
# mediaCount                                                       22
# location                                                        TN
# protected                                                     False
# linkUrl                                                        None
# linkTcourl                                                     None
# profileImageUrl   https://pbs.twimg.com/profile_images/138032396...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/25778718...
# url                               https://twitter.com/thatangellove
#
#                                                                   2  \
# username                                               chainofbeing
# displayname         Chain of Being | Mythic Science Fiction Podcast
# id                                               836274023180951552
# description       A glimpse into the future: where gods control ...
# rawDescription    A glimpse into the future: where gods control ...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2017-02-27T17:57:19+00:00
# followersCount                                                  669
# friendsCount                                                   1086
# statusesCount                                                  2114
# favouritesCount                                                6229
# listedCount                                                       8
# mediaCount                                                       99
# location
# protected                                                     False
# linkUrl                    https://www.patreon.com/faustiannonsense
# linkTcourl                                  https://t.co/hI7TP3NOSh
# profileImageUrl   https://pbs.twimg.com/profile_images/131637658...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/83627402...
# url                                https://twitter.com/chainofbeing
#
#                                                                   3  \
# username                                            greenhorizonpod
# displayname         The Green Horizon | Irish Indie Audio Drama 🇮🇪🚀
# id                                              1212088323885301760
# description       That show about Irish people in space. Proud m...
# rawDescription    That show about Irish people in space. Proud m...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2019-12-31T19:09:21+00:00
# followersCount                                                  881
# friendsCount                                                    670
# statusesCount                                                  1591
# favouritesCount                                                2923
# listedCount                                                       8
# mediaCount                                                      272
# location                                     Waterford, Ireland 🇮🇪
# protected                                                     False
# linkUrl           https://www.faustiannonsense.com/the-green-hor...
# linkTcourl                                  https://t.co/3DrySkK3en
# profileImageUrl   https://pbs.twimg.com/profile_images/136388024...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/12120883...
# url                             https://twitter.com/greenhorizonpod
#
#                                                                   4  \
# username                                                 CaseyBroda
# displayname                                             Casey Broda
# id                                                        533456292
# description          Podcast Editor & Manager. Photographer. Hiker.
# rawDescription       Podcast Editor & Manager. Photographer. Hiker.
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2012-03-22T18:35:49+00:00
# followersCount                                                  415
# friendsCount                                                    431
# statusesCount                                                  2216
# favouritesCount                                               14573
# listedCount                                                       6
# mediaCount                                                      626
# location                                      Currently Seattle, WA
# protected                                                     False
# linkUrl                                      https://caseybroda.com
# linkTcourl                                  https://t.co/5brq3XKxE1
# profileImageUrl   https://pbs.twimg.com/profile_images/136048576...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/53345629...
# url                                  https://twitter.com/CaseyBroda
#
#                                                                   5
# username                                                    bl_save
# displayname                                BL Can't Save You But...
# id                                              1384179676491390978
# description       Offical account for 'BL Can't Save You But...'...
# rawDescription    Offical account for 'BL Can't Save You But...'...
# descriptionUrls                                                  []
# verified                                                      False
# created                                   2021-04-19T16:22:40+00:00
# followersCount                                                   46
# friendsCount                                                     40
# statusesCount                                                   125
# favouritesCount                                                 102
# listedCount                                                       0
# mediaCount                                                       12
# location                                            California, USA
# protected                                                     False
# linkUrl                              https://anchor.fm/ana-castro81
# linkTcourl                                  https://t.co/kOrzzHzYyK
# profileImageUrl   https://pbs.twimg.com/profile_images/138423224...
# profileBannerUrl  https://pbs.twimg.com/profile_banners/13841796...
# url                                     https://twitter.com/bl_save

# %%
print(pod_rev_users.columns)
pod_rev_users.shape
# Out:
# Index(['username', 'displayname', 'id', 'description', 'rawDescription',
#        'descriptionUrls', 'verified', 'created', 'followersCount',
#        'friendsCount', 'statusesCount', 'favouritesCount', 'listedCount',
#        'mediaCount', 'location', 'protected', 'linkUrl', 'linkTcourl',
#        'profileImageUrl', 'profileBannerUrl', 'url'],
#       dtype='object')
# (617, 21)

# %% [markdown]
# # Clean User Data

# %%
df_users = pod_rev_users.loc[:, ['id','username', 'displayname', 'location', 'created', 'followersCount', 'friendsCount', 'url', 'verified' ]]

# %%
def location_extraction (df):
    '''Creates creates a geotext column to extract city and country info if possible'''

    df.loc[:, "location"] = df.loc[:, "location"].fillna("blank")
    df.loc[:, "geotext"] = df.loc[:, "location"].apply(GeoText)
    df.loc[:, 'city'] = df.loc[:, 'geotext'].apply(lambda x: x.cities)
    df.loc[:, 'country'] = df.loc[:, 'geotext'].apply(lambda x: x.countries)
    
    return df

df_users = location_extraction(df_users)

# %%
from geonamescache import GeonamesCache
gc = GeonamesCache()
countries = gc.get_countries()
country_info = pd.DataFrame(countries).T
country_info = country_info.set_index('geonameid').reset_index()
name_code = country_info.loc[:, ["name", "iso3"]]

us_states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
             "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA",
             "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY",
             "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX",
             "UT", "VT", "VA", "WA", "WV", "WI", "WY", "USA", "United States",
             'Seattle', "Los Angeles", "Houston", "Atlanta", "Pittsburgh"]

us_state_names = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", 
               "District ", "of Columbia", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", 
               "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", 
               "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", 
               "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", 
               "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", 
               "Wisconsin", "West Virginia", "Wyoming"]

can_prov_abbrev = {'Alberta': 'AB','British Columbia': 'BC','Manitoba': 'MB', 'New Brunswick': 'NB',
                       'Newfoundland and Labrador': 'NL', 'Northwest Territories': 'NT','Nova Scotia': 'NS','Nunavut': 'NU',
                       'Ontario': 'ON','Prince Edward Island': 'PE', 'Quebec': 'QC','Saskatchewan': 'SK','Yukon': 'YT'}

can_prov_names, can_prov_abbr = zip(*can_prov_abbrev.items())

uk = ["England", 'Wales', "Scotland", 'London', "Manchester", "Isle of Wight", "Northern Ireland", "United Kingdom", 'Bailiwick of Guernsey', "UK", "Hoxton", "Jersey"]

india_city = ["Bangalore", "Delhi", "Hyderabad", "Bengaluru"]

german_city = ["Munich", "Berlin", "eisgau","Hamburg", "Dortmund"]

south_africa = ["South Africa", "Durban", "Johannesburg"]

south_korea = ["Republic of Korea"]

uae = ['UAE', 'Dubai', 'Abu Dhabi']


def replacer(area, name):
    df_users.loc[(df_users.location.str.contains('|'.join(area))), "country"] = name    
    return df_users

def list_to_string(df):
    df["city"] = df['city'].apply(lambda x: "".join(map(str, x)))
    df["country"] = df['country'].apply(lambda x: "".join(map(str, x)))
    
    return df

# %%
def location_cleaner(df):
    df = replacer(can_prov_names, "Canada")
    df = replacer(can_prov_abbrev, "Canada")
    df = replacer(us_state_names, "United States")
    df = replacer(us_states, "United States")
    df = replacer(uk, "United Kingdom")
    df = replacer(german_city, "Germany")
    df = replacer(south_africa, "South Africa")
    df = replacer(india_city, "India")
    df = replacer(uae, 'United Arab Emirates')
    df = replacer(south_korea, "South Korea")
    df.loc[(df.location == "Italia"), "country"] = "Italy" 
    df.loc[(df.location == "Belgrade"), "country"] = "Serbia" 
    df.loc[(df.country == "PolandSerbia"), "country"] = "Poland" 
    df = list_to_string(df)
    
    return df

# %%
df_users = location_cleaner(df_users)
df_users.loc[(df_users.country == "PolandSerbia"), "country"] = "Poland"

# %%
df_users.country.value_counts()
# Out:
#                         290
# United States           204
# United Kingdom           55
# Canada                   26
# Germany                   6
# Ireland                   4
# Australia                 3
# Croatia                   3
# Spain                     3
# Poland                    3
# India                     3
# New Zealand               3
# France                    2
# Malaysia                  2
# South Africa              2
# Sweden                    1
# Italy                     1
# Nigeria                   1
# Ecuador                   1
# South Korea               1
# United Arab Emirates      1
# Czech Republic            1
# Vanuatu                   1
# Name: country, dtype: int64

# %%
df_users_full = pd.merge(left=df_users,
                    right=name_code,
                    how='left',
                    left_on='country',
                    right_on='name')

# %%
df_users_full.head()
# Out:
#                     id         username  \
# 0           2577871830    thatangellove
# 1   836274023180951552     chainofbeing
# 2  1212088323885301760  greenhorizonpod
# 3            533456292       CaseyBroda
# 4  1384179676491390978          bl_save
#
#                                        displayname                location  \
# 0                                  Angel Lovecchio                     TN
# 1  Chain of Being | Mythic Science Fiction Podcast
# 2  The Green Horizon | Irish Indie Audio Drama 🇮🇪🚀  Waterford, Ireland 🇮🇪
# 3                                      Casey Broda   Currently Seattle, WA
# 4                         BL Can't Save You But...         California, USA
#
#                      created  followersCount  friendsCount  \
# 0  2014-06-20T02:43:31+00:00              56           259
# 1  2017-02-27T17:57:19+00:00             669          1086
# 2  2019-12-31T19:09:21+00:00             881           670
# 3  2012-03-22T18:35:49+00:00             415           431
# 4  2021-04-19T16:22:40+00:00              46            40
#
#                                    url  verified  \
# 0    https://twitter.com/thatangellove     False
# 1     https://twitter.com/chainofbeing     False
# 2  https://twitter.com/greenhorizonpod     False
# 3       https://twitter.com/CaseyBroda     False
# 4          https://twitter.com/bl_save     False
#
#                                              geotext       city  \
# 0  <geotext.geotext.GeoText object at 0x7f1819ce0...
# 1  <geotext.geotext.GeoText object at 0x7f1819ce0...
# 2  <geotext.geotext.GeoText object at 0x7f1819ce0...  Waterford
# 3  <geotext.geotext.GeoText object at 0x7f1819ce0...
# 4  <geotext.geotext.GeoText object at 0x7f1819ce0...
#
#          country           name iso3
# 0  United States  United States  USA
# 1                           NaN  NaN
# 2        Ireland        Ireland  IRL
# 3  United States  United States  USA
# 4  United States  United States  USA

# %% [markdown]
# ## Save the Users

# %%
df_users.to_csv('data/user_data.csv')

# %% [markdown]
# # Merge User's Geographic Data with Tweets

# %%
full_df = pd.merge(left=df_tweets, 
                   right=df_users, 
                   how='left',
                   on='username')

full_df.to_csv('data/tweets_users_oct_21.csv', index=False)

# %%
full_df.shape
# Out:
# (3163, 33)

# %%
full_df.head()
# Out:
#                                                url_x  \
# 0  https://twitter.com/thatangellove/status/14469...
# 1  https://twitter.com/thatangellove/status/14469...
# 2  https://twitter.com/chainofbeing/status/144691...
# 3  https://twitter.com/greenhorizonpod/status/144...
# 4  https://twitter.com/CaseyBroda/status/14468808...
#
#                        date  \
# 0 2021-10-09 22:50:07+00:00
# 1 2021-10-09 22:49:05+00:00
# 2 2021-10-09 19:10:55+00:00
# 3 2021-10-09 19:03:17+00:00
# 4 2021-10-09 16:50:48+00:00
#
#                                              content  \
# 0  TODAY IS #PodRevDay!!!!!!!\n\n  1. Leave a pod...
# 1  TODAY IS #PodRevDay!!!!!!!\n\n  1. Leave a pod...
# 2  Hey, guess what?\nYou should drop a review for...
# 3  Am I too late for #PodRevDay ? Yes...Most defi...
# 4  Yesterday was #PodRevDay but this morning I li...
#
#                                      renderedContent                 id_x  \
# 0  TODAY IS #PodRevDay!!!!!!!\n\n  1. Leave a pod...  1446971262782386179
# 1  TODAY IS #PodRevDay!!!!!!!\n\n  1. Leave a pod...  1446971005432483852
# 2  Hey, guess what?\nYou should drop a review for...  1446916099677827074
# 3  Am I too late for #PodRevDay ? Yes...Most defi...  1446914179768664067
# 4  Yesterday was #PodRevDay but this morning I li...  1446880840869289984
#
#                                                 user  \
# 0  {'username': 'thatangellove', 'displayname': '...
# 1  {'username': 'thatangellove', 'displayname': '...
# 2  {'username': 'chainofbeing', 'displayname': 'C...
# 3  {'username': 'greenhorizonpod', 'displayname':...
# 4  {'username': 'CaseyBroda', 'displayname': 'Cas...
#
#                                             outlinks  \
# 0  [https://www.podchaser.com/podcasts/clearing-c...
# 1  [https://www.podchaser.com/podcasts/curious-id...
# 2                                                 []
# 3  [https://www.podchaser.com/podcasts/the-green-...
# 4  [https://open.spotify.com/episode/1rayJEyhthua...
#
#                  tcooutlinks  replyCount  retweetCount  ...  \
# 0  [https://t.co/UnsE0dnB6B]           0             0  ...
# 1  [https://t.co/rg30RyvLYi]           0             0  ...
# 2                         []           0             3  ...
# 3  [https://t.co/vFhNhYDvp9]           0             4  ...
# 4  [https://t.co/WNzDjoC2bH]           0             2  ...
#
#                                        displayname                location  \
# 0                                  Angel Lovecchio                     TN
# 1                                  Angel Lovecchio                     TN
# 2  Chain of Being | Mythic Science Fiction Podcast
# 3  The Green Horizon | Irish Indie Audio Drama 🇮🇪🚀  Waterford, Ireland 🇮🇪
# 4                                      Casey Broda   Currently Seattle, WA
#
#                      created followersCount friendsCount  \
# 0  2014-06-20T02:43:31+00:00             56          259
# 1  2014-06-20T02:43:31+00:00             56          259
# 2  2017-02-27T17:57:19+00:00            669         1086
# 3  2019-12-31T19:09:21+00:00            881          670
# 4  2012-03-22T18:35:49+00:00            415          431
#
#                                  url_y verified  \
# 0    https://twitter.com/thatangellove    False
# 1    https://twitter.com/thatangellove    False
# 2     https://twitter.com/chainofbeing    False
# 3  https://twitter.com/greenhorizonpod    False
# 4       https://twitter.com/CaseyBroda    False
#
#                                              geotext       city        country
# 0  <geotext.geotext.GeoText object at 0x7f1819ce0...             United States
# 1  <geotext.geotext.GeoText object at 0x7f1819ce0...             United States
# 2  <geotext.geotext.GeoText object at 0x7f1819ce0...
# 3  <geotext.geotext.GeoText object at 0x7f1819ce0...  Waterford        Ireland
# 4  <geotext.geotext.GeoText object at 0x7f1819ce0...             United States
#
# [5 rows x 33 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv('data/tweets_users_oct_21.csv')

# %%
# df['freq'] = df.groupby('a')['a'].transform('count')


df['count'] = df.groupby('username')['username'].transform('count')

# %%
df.sort_values(by='count')
# Out:
#                                                   url_x  \
# 1581  https://twitter.com/BookingPod/status/13587979...
# 1727  https://twitter.com/PodRealms/status/133642444...
# 1730  https://twitter.com/TedHudson_/status/13364089...
# 338   https://twitter.com/BrettFishA/status/14353373...
# 337   https://twitter.com/notaladypodcast/status/143...
# ...                                                 ...
# 2100  https://twitter.com/PodRevDay/status/130333134...
# 2101  https://twitter.com/PodRevDay/status/130333119...
# 2104  https://twitter.com/PodRevDay/status/130332966...
# 117   https://twitter.com/PodRevDay/status/144647716...
# 1843  https://twitter.com/PodRevDay/status/132550673...
#
#                            date  \
# 1581  2021-02-08 15:20:56+00:00
# 1727  2020-12-08 21:36:32+00:00
# 1730  2020-12-08 20:34:58+00:00
# 338   2021-09-07 20:21:13+00:00
# 337   2021-09-07 20:25:20+00:00
# ...                         ...
# 2100  2020-09-08 13:56:21+00:00
# 2101  2020-09-08 13:55:46+00:00
# 2104  2020-09-08 13:49:41+00:00
# 117   2021-10-08 14:06:46+00:00
# 1843  2020-11-08 18:33:27+00:00
#
#                                                 content  \
# 1581  So cool! \nHappy #PodRevDay 🥳🥳🥳 !!!!! https://...
# 1727  Today is #PodRevDay, praise is the currency th...
# 1730  @GreenBenchStory I've left my review for @gree...
# 338   September 8th is Podcast Review Day, #podrevda...
# 337   #PodRevDay is coming up! Which shows will you ...
# ...                                                 ...
# 2100  @themenasaur @SeenNotHeardPod @Podchaser Now t...
# 2101  @DanRMorris hi @danrmo, this sounds great. Wha...
# 2104  P\nO\nD\nR\nE\nV\nD\nA\nY\nis \nhere! \n1. wri...
# 117   @Podchaser @Podchaser the email you sent out t...
# 1843  @MikePetersonAL @BreneBrown Awesome Mike, I ad...
#
#                                         renderedContent                 id_x  \
# 1581  So cool! \nHappy #PodRevDay 🥳🥳🥳 !!!!! twitter....  1358797970225979397
# 1727  Today is #PodRevDay, praise is the currency th...  1336424446756786176
# 1730  @GreenBenchStory I've left my review for @gree...  1336408951739584517
# 338   September 8th is Podcast Review Day, #podrevda...  1435337379615756296
# 337   #PodRevDay is coming up! Which shows will you ...  1435338415906557953
# ...                                                 ...                  ...
# 2100  @themenasaur @SeenNotHeardPod @Podchaser Now t...  1303331342319587332
# 2101  @DanRMorris hi @danrmo, this sounds great. Wha...  1303331197288960000
# 2104  P\nO\nD\nR\nE\nV\nD\nA\nY\nis \nhere! \n1. wri...  1303329664761556993
# 117   @Podchaser @Podchaser the email you sent out t...  1446477169719451648
# 1843  @MikePetersonAL @BreneBrown Awesome Mike, I ad...  1325506735977754624
#
#                                                    user  \
# 1581  {'username': 'BookingPod', 'displayname': 'Pod...
# 1727  {'username': 'PodRealms', 'displayname': 'Litt...
# 1730  {'username': 'TedHudson_', 'displayname': 'Ted...
# 338   {'username': 'BrettFishA', 'displayname': 'bre...
# 337   {'username': 'notaladypodcast', 'displayname':...
# ...                                                 ...
# 2100  {'username': 'PodRevDay', 'displayname': 'Podc...
# 2101  {'username': 'PodRevDay', 'displayname': 'Podc...
# 2104  {'username': 'PodRevDay', 'displayname': 'Podc...
# 117   {'username': 'PodRevDay', 'displayname': 'Podc...
# 1843  {'username': 'PodRevDay', 'displayname': 'Podc...
#
#                                                outlinks  \
# 1581  ['https://twitter.com/Podchaser/status/1358772...
# 1727                                                 []
# 1730                                                 []
# 338                        ['http://www.podrevday.com']
# 337   ['https://twitter.com/PodRevDay/status/1435330...
# ...                                                 ...
# 2100                                                 []
# 2101                                                 []
# 2104                       ['http://www.podrevday.com']
# 117     ['https://www.youtube.com/watch?v=VF-r5TtlT9w']
# 1843                                                 []
#
#                       tcooutlinks  replyCount  retweetCount  ...  \
# 1581  ['https://t.co/uaTiR09KgB']           1             0  ...
# 1727                           []           2             4  ...
# 1730                           []           0             2  ...
# 338   ['https://t.co/GIzXBOm0iP']           1             4  ...
# 337   ['https://t.co/8jWY0N48oN']           1             1  ...
# ...                           ...         ...           ...  ...
# 2100                           []           0             0  ...
# 2101                           []           0             0  ...
# 2104  ['https://t.co/oet2vmUjAb']           4            10  ...
# 117   ['https://t.co/5dzDQqLD4d']           0             0  ...
# 1843                           []           1             0  ...
#
#                      location                    created  followersCount  \
# 1581                      NaN  2020-07-29T14:04:50+00:00             289
# 1727            United States  2018-08-08T01:30:46+00:00            2101
# 1730        Hamilton, Ontario  2010-08-20T16:55:08+00:00            3757
# 338   Cape Town, South Africa  2009-04-25T15:01:42+00:00            7537
# 337                       NaN  2020-08-04T23:42:51+00:00             145
# ...                       ...                        ...             ...
# 2100      Republic of Croatia  2020-05-07T19:40:12+00:00            1780
# 2101      Republic of Croatia  2020-05-07T19:40:12+00:00            1780
# 2104      Republic of Croatia  2020-05-07T19:40:12+00:00            1780
# 117       Republic of Croatia  2020-05-07T19:40:12+00:00            1780
# 1843      Republic of Croatia  2020-05-07T19:40:12+00:00            1780
#
#      friendsCount                                url_y verified  \
# 1581          407       https://twitter.com/BookingPod    False
# 1727         1757        https://twitter.com/PodRealms    False
# 1730         4993       https://twitter.com/TedHudson_    False
# 338          8064       https://twitter.com/BrettFishA    False
# 337           110  https://twitter.com/notaladypodcast    False
# ...           ...                                  ...      ...
# 2100         1905        https://twitter.com/PodRevDay    False
# 2101         1905        https://twitter.com/PodRevDay    False
# 2104         1905        https://twitter.com/PodRevDay    False
# 117          1905        https://twitter.com/PodRevDay    False
# 1843         1905        https://twitter.com/PodRevDay    False
#
#                                                 geotext             city  \
# 1581  <geotext.geotext.GeoText object at 0x7f181a08e...              NaN
# 1727  <geotext.geotext.GeoText object at 0x7f181a08e...              NaN
# 1730  <geotext.geotext.GeoText object at 0x7f181a08e...  HamiltonOntario
# 338   <geotext.geotext.GeoText object at 0x7f1819e98...        Cape Town
# 337   <geotext.geotext.GeoText object at 0x7f1819e98...              NaN
# ...                                                 ...              ...
# 2100  <geotext.geotext.GeoText object at 0x7f1819ce0...              NaN
# 2101  <geotext.geotext.GeoText object at 0x7f1819ce0...              NaN
# 2104  <geotext.geotext.GeoText object at 0x7f1819ce0...              NaN
# 117   <geotext.geotext.GeoText object at 0x7f1819ce0...              NaN
# 1843  <geotext.geotext.GeoText object at 0x7f1819ce0...              NaN
#
#             country count
# 1581            NaN     1
# 1727  United States     1
# 1730         Canada     1
# 338    South Africa     1
# 337             NaN     1
# ...             ...   ...
# 2100        Croatia   421
# 2101        Croatia   421
# 2104        Croatia   421
# 117         Croatia   421
# 1843        Croatia   421
#
# [3163 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['url_x', 'date', 'content', 'renderedContent', 'id_x', 'user',
#        'outlinks', 'tcooutlinks', 'replyCount', 'retweetCount', 'likeCount',
#        'quoteCount', 'conversationId', 'lang', 'source', 'sourceUrl',
#        'sourceLabel', 'media', 'retweetedTweet', 'quotedTweet',
#        'mentionedUsers', 'username', 'id_y', 'displayname', 'location',
#        'created', 'followersCount', 'friendsCount', 'url_y', 'verified',
#        'geotext', 'city', 'country', 'count'],
#       dtype='object')

# %%
keep = ['username', 'id_y', 'displayname', 'location',
        'created', 'followersCount', 'friendsCount', 'url_y', 'verified',
        'city', 'country', 'count']

df.loc[:, keep].drop_duplicates().sort_values(by='count').to_csv('data/user_data_count_10_21.csv', index=False)
